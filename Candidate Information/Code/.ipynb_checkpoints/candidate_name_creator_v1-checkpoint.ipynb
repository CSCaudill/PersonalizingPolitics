# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import matplotlib #for fuller functionality, incl. colors
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GMM
from matplotlib.colors import LogNorm
import pandas as pd
from IPython.display import display

from sklearn import mixture

# Remove Deprecation warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# for nicer printing
from prettytable import PrettyTable

#increase number of columns can see in pandas
pd.set_option('display.max_columns', 100)

# %% [markdown]
# **LOAD DF**

# %%
df = pd.DataFrame.from_csv("text_files/senate_results_EDA_states_all_years.csv")

# add full name

def replace_spaces(name) :
    return name.replace(" ","_")

df['full_name'] = df['candidate'].apply(replace_spaces)
# df.set_index("full_name", inplace = True)

display(df.head(5))
# Out:
#    year              candidate state_abbr      votes  votes_state  max_state  \
# 0  2010  Alexander Giannoulias         IL  1719478.0      3703901    1778698
# 1  2010           Alvin Greene         SC   364598.0      1318794     810771
# 2  2010                 Aurora         SD        NaN            0          0
# 3  2010          Barbara Boxer         CA  5218441.0     10000093    5218441
# 4  2010       Barbara Mikulski         MD  1140531.0      1833304    1140531
#
#   %_votes_state  winner              full_name
# 0         46.4%       0  Alexander_Giannoulias
# 1         27.6%       0           Alvin_Greene
# 2           NaN       1                 Aurora
# 3         52.2%       1          Barbara_Boxer
# 4         62.2%       1       Barbara_Mikulski

# %% [markdown]
# Idea: apply URL as best as possible from name
# for those candidates with > 5% vote share that didn't match to a url, see if can get a match
# For all that match, try to pull table

# %%
### GET URL, WRITE TO FILE ###
#~~UNCOMMENT TO ACTUALLY WRITE~~#

for name, results in zip(df['full_name'], df['%_votes_state']) :
    try :
        url = 'http://www.ontheissues.org/jidojidfoj'
        response = requests.get(url)
        html = response.content
        soup = BeautifulSoup(html)

        page = urllib2.urlopen(url)
        html_content = page.read()
        rendered_content = html2text.html2text(html_content)
    except :
        print name, results
# Out:
# Alexander_Giannoulias
# Alvin_Greene
# Aurora
# Barbara_Boxer
# Barbara_Mikulski
# Beadle
# Bennett
# Billy_Wilson
# Blanche_Lincoln
# Bon_Homme
# Brad_Ellsworth
# Brookings
# Brown
# Brule
# Buffalo
# Butte
# Cam_Cavasso
# Campbell
# Carly_Fiorina
# Charles_Grassley
# Charles_Mix
# Charles_Schumer
# Charley_Miller
# Charlie_Crist
# Charlie_Melancon
# Chris_Booth
# Chuck_Donovan
# Clark
# Clay
# Codington
# Corson
# Custer
# Dan_Coats
# Daniel_Freilich
# Daniel_Inouye
# David_Nolan
# David_Vitter
# Davison
# Day
# Deuel
# Dewey
# Dino_Rossi
# Douglas
# Edmunds
# Elaine_Marshall
# Eric_Wargotz
# Ernest_Wooton
# Fall_River
# Faulk
# Gail_Lightfoot
# Grant
# Gregory
# Haakon
# Hamlin
# Hand
# Hanson
# Harding
# Harry_Reid
# Hughes
# Hutchinson
# Hyde
# Jack_Conway
# Jackson
# Jay_Townsend
# Jeff_Jarrett
# Jerauld
# Jerry_Moran
# Dan_Chapin
# Darryl_Glenn
# David_Duke
# Deborah_Ross
# Derrick_Edwards
# Donald_Crawford
# Edward_Clifford
# Eliot_Glassheim
# Eric_Navickas
# Evan_Bayh
# Foster_Campbell
# Frank_Gilbert
# Fred_Ryman
# Gary_Landrieu
# Gary_Swing
# Gregory_Taylor
# James_Germalic
# James_Lankford
# Jarrod_Williams
# Jason_Kander
# Jay_Williams
# Jeffery_Russell
# Jerry_Moran
# Jerry_Sturgill
# Jerry_Trudell
# Jim_Barksdale
# Jim_Gray
# Jim_Hennager
# Jim_Lindsay
# Joe_Heck
# Joe_Miller
# John_Boozman
# John_Carroll
# John_Fleming
# John_Hoeven
# John_Kennedy
# John_McCain
# John_Thune
# Johnathan_McFarland
# Johnny_Isakson
# Jonathan_Dine
# Joseph_Cao
# Joseph_DeMare
# Joshua_Pellerin
# Joy_Allison
# Kaitlin_Marone
# Kamala_Harris
# Kathy_Szeliga
# Katie_McGinty
# Kelly_Ayotte
# Kenton_McMillen
# Le_Roy_Gillam
# Lily_Williams
# Lisa_Murkowski
# Loretta_Sanchez
# Lucy_Brenton
# Maggie_Hassan
# Marco_Rubio
# Margaret_Flowers
# Margaret_Stock
# Mark_Beard
# Mark_Callahan
# Mark_Kirk
# Michael_Bennet
# Michael_Kokoski
# Michael_Luick-Thrams
# Mike_Crapo
# Mike_Lee
# Mike_Workman
# Misty_Snow
# None_of_these_candidates
# Pat_Toomey
# Patrick_Leahy
# Patrick_Murphy
# Patrick_Wiesner
# Patty_Judge
# Patty_Murray
# Paul_Fiorino
# Paul_Stanton
# Pete_Diamondstone
# Peter_Williams
# Phil_Anderson
# Rand_Paul
# Ray_Metcalfe
# Ray_Writz
# Rebel_Michael_Scarborough
# Richard_Blumenthal
# Richard_Burr
# Richard_Lion
# Richard_Shelby
# Rob_Maness
# Rob_Portman
# Robert_Garrard
# Robert_Marquette
# Robert_Murphy
# Robin_Wilson
# Ron_Crumpton
# Ron_Johnson
# Ron_Wyden
# Roy_Blunt
# Russ_Feingold
# Scott_Milne
# Scott_Rupert
# Scott_Summers
# Sean_Braddy
# Sean_Haugh
# Shanti_Lewallen
# Steven_Machat
# Steven_Reynolds
# Stoney_Fonua
# Tammy_Duckworth
# Ted_Gianoutsos
# Ted_Strickland
# Thomas_Clements
# Thomas_Dixon
# Tim_Scott
# Todd_Young
# Tom_Connors
# Tom_Jones
# Tom_Sawyer
# Tony_Gumina
# Tony_Khoury
# Troy_Hebert
# Vinny_Mendoza
# Wendy_Long
# NameErrorTraceback (most recent call last)
# <ipython-input-5-3e3a0410ae5d> in <module>()
#       7
#       8 url = 'http://www.ontheissues.org/jidojidfoj'
# ----> 9 response = requests.get(url)
#      10 html = response.content
#      11 soup = BeautifulSoup(html)
#
# NameError: name 'requests' is not defined
