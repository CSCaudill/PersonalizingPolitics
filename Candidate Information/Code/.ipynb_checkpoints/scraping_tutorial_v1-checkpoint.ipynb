# %%
# !pip install BeautifulSoup
# !pip install Requests
# Out:
# Collecting BeautifulSoup
#   Downloading BeautifulSoup-3.2.1.tar.gz
# Building wheels for collected packages: BeautifulSoup
#   Running setup.py bdist_wheel for BeautifulSoup: started
#   Running setup.py bdist_wheel for BeautifulSoup: finished with status 'done'
#   Stored in directory: C:\Users\kowen\AppData\Local\pip\Cache\wheels\5e\be\6d\ed01d5d434a821557b674c9da976f60b1b93d9009447eb9d16
# Successfully built BeautifulSoup
# Installing collected packages: BeautifulSoup
# Successfully installed BeautifulSoup-3.2.1
# Requirement already satisfied: Requests in c:\users\kowen\appdata\local\continuum\anaconda2\lib\site-packages

# %% [markdown]
# tutorial link: web scraping: http://first-web-scraper.readthedocs.io/en/latest/#act-3-web-scraping
# See notes at this link.

# %%
# %%writefile scrape.py

import requests

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content
print html
# Out:
# <!DOCTYPE html>
# <html>
#     <head>        <title>Current Detainees of Boone County Jail</title>
#         <meta content="IE=edge" http-equiv="X-UA-Compatible" />
#         <meta content="width=device-width, initial-scale=1.0" name="viewport" />
# <!--  -->
# <!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->
#         <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon" />
#         <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css" />
#         <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css" />
#         <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css" />
# <!--[if !IE]>
# <link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />
# <![endif]-->
# <!--[if IE 7]>
# <link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />
# <![endif]-->
#         <style type="text/css">#sort_table_head a {pointer-events: none;}
#           #sort_table_head i {display: none;}
#       #sort_table_head [data-col="LASTNP"] a,
#       #sort_table_head [data-col="FIRSTP"] a {
#             pointer-events: initial;}
#       #sort_table_head [data-col="LASTNP"] i,
#       #sort_table_head [data-col="FIRSTP"] i {
#             display: initial;}
#           .viewCount {text-align: center;}
#           .filterOptions.mobileOnly {display: none;}
#           /*@media screen and (min-width: 761px) {
#             body > div.ui-dialog {
#               top: 50% !important;
#               transform: translateY(-50%);
#             }
#           }*/</style>
# <script type="text/javascript" src="/mrcjava/mrcclasses/mpowerapps.js"></script>
# <script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" mrcfile="mobileSortAndFilter.js"></script>
# <script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" mrcfile="websiteNotification.js"></script>
# <script type="text/javascript">
#       var s1 = new Image().src = '/mrcjava/image/ascg.gif',
#           s0 = new Image().src = '/mrcjava/image/descg.gif';
#     </script>
#     </head>
#
#     <body>
# <!-- Begin mrc Header -->
#         <div class="page-wrap">
# <!---->
# <!-- Begin mrc Default Desktop Header -->
# <!-- Begin JavaScript Required Message -->
# <noscript>
# 	<div class="warning noJS">
# 		The Boone County website <strong>requires</strong> JavaScript to function correctly. Please enable JavaScript in your browser.
# 	</div>
# </noscript>
# <!-- End JavaScript Required Message -->
# <!-- Begin Image Bar -->
# <div class="pageHeader DepartmentHeader container">
#   <div class="DepartmentHeaderGraphic">
#     <img src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" alt="Boone County Sheriff's Badge" />
#   </div>
#   <div class="DepartmentHeaderInfo">
#     <div class="DepartmentHeaderTitle">
#       Boone County Sheriff's Department
#     </div>
#     <div class="container">
#       <div class="DepartmentHeaderAddress">
#         Boone County Sheriff's Department<br />
#         2121 County Dr.<br />
#         Columbia, MO 65202
#       </div>
#       <div class="DepartmentHeaderNumbers">
#         Office (573) 875-1111<br />
#         Fax (573) 874-8953
#       </div>
#     </div>
#   </div>
# </div>
# <!-- End Image Bar -->
# <!-- Begin Link Bar -->
# <div id="headerMenu" class="container noPrint">
#   <ul>
#     <li>
#       <a href="http://www.boonecountymo.org/sheriff">
#         Home
#       </a>
#     </li>
#     <li class="mainMenu">
#       <a href="/mrcjava/servlet/SH01_MP.I00040s">
#         Menu
#       </a>
#     </li>
#     <li>
#       <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">
#         Help
#       </a>
#     </li>
#     <!--<li class="options">
#       <a href="#"  onclick="viewOptions();">
#         Options
#       </a>
#     </li>-->
#   </ul>
# </div>
# <!-- End Link Bar -->
# <!-- End mrc Default Desktop Header -->
# <!-- Begin BC Custom Mobile Header-->
# <div class="fixedHeader">
#   <div class="fixedHeaderButton bcSealButton">
#   <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#     <img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" class="bcSeal shBadge" />
#   </a>
#   </div>
#   <div class="fixedHeaderButton menuButton">
#   <!--Link to custom menu page-->
#   <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00040s">Menu</a>
#   </div>
#   <!--<div class="options fixedHeaderButton optionsButton">
#   <a class="transparent" href="#" id="options" onclick="viewOptions();">
#     <i class="fa fa-2x fa-gear optionsIcon">&nbsp;</i>
#   </a>
#   </div>-->
#   <div class="fixedHeaderButton helpButton">
#   <!--Link to help page-->
#   <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00030s">Help</a>
#   </div>
# 	<div class="fixedHeaderButton optionsButton hiddenButton">
#   </div>
#   <div class="headerTitle">
#   <!--Link to department home page-->
#   <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">Boone County Sheriff's Department</a>
#   </div>
# </div>
# <!-- End BC Custom Mobile Header-->
# <script type="text/javascript">
#  if (window.location.hostname == "s10ccd5c.boonecountymo.org") {
#    jQuery('a[href="/mrcjava/servlet/BC00_MP.mrcMenu"]').attr(
#      'href',
#      '/mrcjava/servlet/MRCTEST.mrcMenu'
#    );
#  }
# </script>
# <!---->
#
# <!-- End mrc Header -->
# <!-- Begin Title Bar -->
#         <div class="title">Current Detainees of Boone County Jail</div>
# <!-- End Title Bar -->
# <!---->
# <div style="padding: 10px; DISPLAY: none; FONT: 8pt verdana;" id="applicationOptions">
#                     <table class="collapse BCSDTable shadow"  cellspacing="0" cellpadding="0">
#                         <tbody>
#                             <tr class="even">
# 							<!-- -->
#                                 <td class="two" valign="top" style="border-bottom:1px solid #000">
#                                 <table border="0" cellspacing="1" cellpadding="1" width="350" class="BCSDTable">
#                                     <tbody>
#                                         <tr>
#                                             <th>Saved Searches</th>
#                                         </tr>
#                                         <tr>
#                                             <td style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px" align="left">
# 												<div id="search_input"><br />
# 													<font size="2"><strong>Name Current Search:</strong><br /></font>
# 												&nbsp;&nbsp;&nbsp; <input id="dialogViewName" size="35" name="dialogViewName" />
# 												&nbsp;<img style="CURSOR: pointer" onclick="saveView();" alt="" width="20" height="19" src="/mrcjava/image/view_save.png" />
# 													<br />
# 												</div>
# 												<br /><font size="2"><strong>Execute Saved Search:</strong></font><br /><table mrc_app="SH01_MP.I00290s" border="0" cellspacing="1" cellpadding="1"><tbody></tbody></table>
#  <br />
# 											</td>
#                                         </tr>
#                                     </tbody>
#                                 </table>
#                                 </td>
# 							<!-- -->
#                                 <td class="two" valign="top" style="border-bottom:1px solid #000">
#                                 <table border="0" cellspacing="1" cellpadding="1" width="200" class="BCSDTable">
#                                     <tbody>
#                                         <tr>
#                                             <th>Browser Mode</th>
#                                         </tr>
#                                         <tr>
#                                             <td style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px" align="left">
# 												<br /><font size="2"><strong>Select Browsing Mode:</strong></font>
# 												<br/><br />
# 												<table  id="device_select_table" border="0" cellspacing="1" cellpadding="1"><tbody>
# <tr>
# <td>&nbsp;<img src="/mrcjava/image/check.png"/>
#  </td>
# <td><font size="2">&nbsp;&nbsp;<a href="#" class="standard" onclick="switchDevice('pc')">PC</a></font></td>
# </tr>
# <tr>
# <td>&nbsp;&nbsp;</td>
# <td><font size="2">&nbsp;&nbsp;<a href="#" class="standard" onclick="switchDevice('mob')">Mobile</a></font></td>
# </tr>
# </tbody></table>
#                                             </td>
#                                         </tr>
#                                     </tbody>
#                                 </table>
#                                 </td>
#
#                             </tr>
#                         </tbody>
#                     </table>
#                     </div>
#
# <!---->
#         <div class="ajax_content table-wrapper box-shadow" id="mrcMainContent">
#         <form action="SH01_MP.I00290s" autocomplete="off" data-app_type="I" id="FORM_I00290" method="post" name="FORM_I00290">
# <!-- Begin Run Time Message -->
#             <div class="errortext1"></div>
# <!-- End Run Time Message -->
#             <div class="searchWrapper">
#             <div class="search card">
#             <div class="card-title">Search By Name</div>
#             <div class="card-block">
#             <div><label>Last Name:</label>
# <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">            <option title="Equal" value="EQ">EQ</option>
#             <option title="Not equal" value="NE">NE</option>
#             <option title="Greater than or equal" value="GE">GE</option>
#             <option title="Greater than" value="GT">GT</option>
#             <option title="Less than or equal" value="LE">LE</option>
#             <option title="Less than" value="LT">LT</option>
#             <option title="In the list" value="LS">LS</option>
#             <option title="Not in the list" value="NS">NS</option>
#             <option title="In the range" value="RG">RG</option>
#             <option title="Not in the range" value="NR">NR</option>
#             <option title="Contains" value="CT">CT</option>
#             <option title="Does not Contain" value="NC">NC</option>
#             <option title="Contains all" value="CA">CA</option>
#             <option selected="selected" title="Contains any" value="CO">CO</option>
#             <option title="Starts with" value="SW">SW</option>
#             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="32" title="val_LASTNP" type="text" value="" /></div>
#             <div><label>First Name:</label>
# <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">            <option title="Equal" value="EQ">EQ</option>
#             <option title="Not equal" value="NE">NE</option>
#             <option title="Greater than or equal" value="GE">GE</option>
#             <option title="Greater than" value="GT">GT</option>
#             <option title="Less than or equal" value="LE">LE</option>
#             <option title="Less than" value="LT">LT</option>
#             <option title="In the list" value="LS">LS</option>
#             <option title="Not in the list" value="NS">NS</option>
#             <option title="In the range" value="RG">RG</option>
#             <option title="Not in the range" value="NR">NR</option>
#             <option title="Contains" value="CT">CT</option>
#             <option title="Does not Contain" value="NC">NC</option>
#             <option title="Contains all" value="CA">CA</option>
#             <option selected="selected" title="Contains any" value="CO">CO</option>
#             <option title="Starts with" value="SW">SW</option>
#             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="32" title="val_FIRSTP" type="text" value="" /></div>
#             <div><button class="btn btn-primary" name="btn_search" type="submit"><i class="fa fa-large fa-search">&nbsp;</i> Search</button><button class="btn btn-default" name="btn_reset" type="reset"><i class="fa fa-large fa-repeat">&nbsp;</i> Reset</button>
# <a class="btn btn-default" href="SH01_MP.R00250s?run=2"><i class="fa fa-large fa-file-excel-o">&nbsp;</i> Export Detainees &amp; Charges to Excel</a>
# </div>
#             </div>
#             <div class="card-block"><strong>Run Date: 10/10/17</strong></div>
#             </div>
#             </div>
# <!-- Begin Data Table -->
# <script> jQuery(document).ready(function(){         var greynames=new Array("s1LASTNP","s1FIRSTP","s1MIDDLP","s1PERKEP"); setSortImage2(greynames,'FORM_I00290'); });  </script>
#             <table cellspacing="0" class="collapse data-table shadow responsive">
#                 <thead>
#                     <tr class="tr-paging">
#                         <th class="th_left paging_row" colspan="93">&nbsp;
# <!---->
# <!--<button class="btn btn-primary" name="btn_search" type="submit"><i class="fa fa-large fa-filter">&nbsp;</i> Filter</button>-->
# &nbsp;242 Total Items &nbsp;|&nbsp; Page Size&nbsp;
# <input class="mrcinput" name="max_rows" size="3" title="max_rowsp" type="text" value="50" /> &nbsp;
# <!--   -->
# <!--
# <img alt class="to-excel-img" src="/mrcjava/image/format_excel.png" title="Microsoft Excel format" /> &nbsp; -->
# <!-- -->
#                             <div class="pagination pagination-right fixed-pagination">
#                             <ul>
#                                 <li>
# <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)"><i class="fa fa-angle-double-left fa-large">&nbsp;</i></a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)"><i class="fa fa-angle-left fa-large">&nbsp;</i></a>
# </li>
#                                 <li class="disabled">
# <a href="#">Page 1 of 5</a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)"><i class="fa fa-angle-right fa-large">&nbsp;</i></a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)"><i class="fa fa-angle-double-right fa-large">&nbsp;</i></a>
# </li>
#                             </ul>
#                             </div>
#                         </th>
#                     </tr>
# <!--BEGIN_SORT_TABLE_HEADER-->
#                     <tr class="table-header" id="sort_table_head">
#                         <th data-col="LASTNP">
# <a class="sort-col" data-field="LASTNP" href="javascript:void(0)">Last Name&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th data-col="FIRSTP">
# <a class="sort-col" data-field="FIRSTP" href="javascript:void(0)">First Name&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="MIDDLP">
# <a class="sort-col" data-field="MIDDLP" href="javascript:void(0)">Middle Name&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="SEXCOP">
# <a class="sort-col" data-field="SEXCOP" href="javascript:void(0)">Sex&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="RACECP">
# <a class="sort-col" data-field="RACECP" href="javascript:void(0)">Race&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="AGEBEP">
# <a class="sort-col" data-field="AGEBEP" href="javascript:void(0)">Age&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="CITYMP">
# <a class="sort-col" data-field="CITYMP" href="javascript:void(0)">City <i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile" data-col="STATEP">
# <a class="sort-col" data-field="STATEP" href="javascript:void(0)">State&nbsp;<i class="fa fa-sort">&nbsp;</i></a>
# </th>
#                         <th class="hideOnMobile">&nbsp;</th>
#                     </tr>
# <!--END_SORT_TABLE_HEADER-->
# <!--BEGIN_ADVANCED_SEARCH-->
# <!---->
#                     <tr id="search_table_head" style="display: none;">
#                         <th align="center">
# <a class="nav" href="/mrcjava/mrcclasses/filter_relationship_help.html" linkedtype target="_blank" title="Filter Relationship Help">?</a>
# <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="6" title="val_LASTNP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="6" title="val_FIRSTP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_MIDDLP" name="rls_MIDDLP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_MIDDLP" name="val_MIDDLP" size="6" title="val_MIDDLP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_SEXCOP" name="rls_SEXCOP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_SEXCOP" name="val_SEXCOP" size="6" title="val_SEXCOP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_RACECP" name="rls_RACECP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_RACECP" name="val_RACECP" size="6" title="val_RACECP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_AGEBEP" name="rls_AGEBEP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_AGEBEP" name="val_AGEBEP" size="6" title="val_AGEBEP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_CITYMP" name="rls_CITYMP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_CITYMP" name="val_CITYMP" size="6" title="val_CITYMP" type="text" value="" /></th>
#                         <th align="center">
# <select class="mrcselect relation" id="F_C_LI_STATEP" name="rls_STATEP">                            <option title="Equal" value="EQ">EQ</option>
#                             <option title="Not equal" value="NE">NE</option>
#                             <option title="Greater than or equal" value="GE">GE</option>
#                             <option title="Greater than" value="GT">GT</option>
#                             <option title="Less than or equal" value="LE">LE</option>
#                             <option title="Less than" value="LT">LT</option>
#                             <option title="In the list" value="LS">LS</option>
#                             <option title="Not in the list" value="NS">NS</option>
#                             <option title="In the range" value="RG">RG</option>
#                             <option title="Not in the range" value="NR">NR</option>
#                             <option title="Contains" value="CT">CT</option>
#                             <option title="Does not Contain" value="NC">NC</option>
#                             <option title="Contains all" value="CA">CA</option>
#                             <option title="Contains any" value="CO">CO</option>
#                             <option title="Starts with" value="SW">SW</option>
#                             <option title="Does not Start with" value="NW">NW</option></select>
# <input class="mrcinput" id="val_STATEP" name="val_STATEP" size="6" title="val_STATEP" type="text" value="" /></th>
#                         <th align="center">&nbsp;</th>
#                     </tr>
# <!--  -->
# </thead>
# <!--END_ADVANCED_SEARCH-->
#                 <tbody class="stripe" id="mrc_main_table">
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">ADAM</td>
#                         <td class="one td_left" data-th="First Name">OMER</td>
#                         <td class="one td_left" data-th="Middle Name">SIRAJ</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">B</td>
#                         <td class="one td_right" data-th="Age">29</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">AKERS</td>
#                         <td class="two td_left" data-th="First Name">BRANDEN</td>
#                         <td class="two td_left" data-th="Middle Name">MICHAEL</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">32</td>
#                         <td class="two td_left" data-th="City">MOKANE</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=51443&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">ALLEN</td>
#                         <td class="one td_left" data-th="First Name">WILLIAM</td>
#                         <td class="one td_left" data-th="Middle Name">LAMAR</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">B</td>
#                         <td class="one td_right" data-th="Age">55</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=19022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">ANDERSON</td>
#                         <td class="two td_left" data-th="First Name">RICHARD</td>
#                         <td class="two td_left" data-th="Middle Name">KENNETH</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">24</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">AVALOS-AVALOS</td>
#                         <td class="one td_left" data-th="First Name">JOSE</td>
#                         <td class="one td_left" data-th="Middle Name"> </td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">H</td>
#                         <td class="one td_right" data-th="Age">19</td>
#                         <td class="one td_left" data-th="City">ST.ANN</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78424&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BARNEY</td>
#                         <td class="two td_left" data-th="First Name">FELSON</td>
#                         <td class="two td_left" data-th="Middle Name">DEVONE</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">40</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=4285&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BARRON</td>
#                         <td class="one td_left" data-th="First Name">DUSTYN</td>
#                         <td class="one td_left" data-th="Middle Name">MICHAEL</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">20</td>
#                         <td class="one td_left" data-th="City">HARTSBURG</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74098&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BLAIR</td>
#                         <td class="two td_left" data-th="First Name">RYAN</td>
#                         <td class="two td_left" data-th="Middle Name">WADE</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">26</td>
#                         <td class="two td_left" data-th="City">MEXICO</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73590&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BLOCKER</td>
#                         <td class="one td_left" data-th="First Name">TRAMELL</td>
#                         <td class="one td_left" data-th="Middle Name">LAMARR</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">B</td>
#                         <td class="one td_right" data-th="Age">39</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BOLEYN</td>
#                         <td class="two td_left" data-th="First Name">TRENTON</td>
#                         <td class="two td_left" data-th="Middle Name">DEAN</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">36</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78034&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BONAPARTE</td>
#                         <td class="one td_left" data-th="First Name">NATHANIEL</td>
#                         <td class="one td_left" data-th="Middle Name">LEROY</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">B</td>
#                         <td class="one td_right" data-th="Age">38</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=18384&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BOSS</td>
#                         <td class="two td_left" data-th="First Name">JAFARI</td>
#                         <td class="two td_left" data-th="Middle Name">RASHIDI</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">34</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BRADEN</td>
#                         <td class="one td_left" data-th="First Name">WILLIAM</td>
#                         <td class="one td_left" data-th="Middle Name">CHRISTOPHER</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">17</td>
#                         <td class="one td_left" data-th="City">HALLSVILLE</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79750&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BRADSHAW</td>
#                         <td class="two td_left" data-th="First Name">JOSEPH</td>
#                         <td class="two td_left" data-th="Middle Name">LEE</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">41</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BRASHIER</td>
#                         <td class="one td_left" data-th="First Name">APRIL</td>
#                         <td class="one td_left" data-th="Middle Name">RAE</td>
#                         <td class="one td_left" data-th="Sex">F</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">43</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=1262&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BRILL</td>
#                         <td class="two td_left" data-th="First Name">BRANDON</td>
#                         <td class="two td_left" data-th="Middle Name">NICHOLAS</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">26</td>
#                         <td class="two td_left" data-th="City">CLARK</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BROWN</td>
#                         <td class="one td_left" data-th="First Name">CLAUDE</td>
#                         <td class="one td_left" data-th="Middle Name">DAVID</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">52</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BROWN</td>
#                         <td class="two td_left" data-th="First Name">THYRUS</td>
#                         <td class="two td_left" data-th="Middle Name">MONTEZ</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">48</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=45497&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">BRUNS</td>
#                         <td class="one td_left" data-th="First Name">MATTHEW</td>
#                         <td class="one td_left" data-th="Middle Name">ELLIOT</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">21</td>
#                         <td class="one td_left" data-th="City">KIRKWOOD</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78785&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">BURRIS</td>
#                         <td class="two td_left" data-th="First Name">GEOFFREY</td>
#                         <td class="two td_left" data-th="Middle Name">DARL</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">28</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
# ...
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41050&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">CROY</td>
#                         <td class="one td_left" data-th="First Name">MARANDA</td>
#                         <td class="one td_left" data-th="Middle Name">LEE</td>
#                         <td class="one td_left" data-th="Sex">F</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">31</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38647&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">DANIELSSON</td>
#                         <td class="two td_left" data-th="First Name">JESSE</td>
#                         <td class="two td_left" data-th="Middle Name">ROBERTO</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">24</td>
#                         <td class="two td_left" data-th="City">LAYTON</td>
#                         <td class="two td_left" data-th="State">UT</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">DAVIS</td>
#                         <td class="one td_left" data-th="First Name">KAYLA</td>
#                         <td class="one td_left" data-th="Middle Name">REBECCA</td>
#                         <td class="one td_left" data-th="Sex">F</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">27</td>
#                         <td class="one td_left" data-th="City">WOOLRIDGE</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61234&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">DAWSON</td>
#                         <td class="two td_left" data-th="First Name">VINCENT</td>
#                         <td class="two td_left" data-th="Middle Name">GESHAI</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">20</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72780&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">DAY</td>
#                         <td class="one td_left" data-th="First Name">MICHAEL</td>
#                         <td class="one td_left" data-th="Middle Name">BRIAN</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">46</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79549&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">DICKERSON</td>
#                         <td class="two td_left" data-th="First Name">CHRISTOPHER</td>
#                         <td class="two td_left" data-th="Middle Name">KEWESI</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">B</td>
#                         <td class="two td_right" data-th="Age">19</td>
#                         <td class="two td_left" data-th="City">NEW ORLEANS</td>
#                         <td class="two td_left" data-th="State">LA</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74118&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">DIXON</td>
#                         <td class="one td_left" data-th="First Name">JAY</td>
#                         <td class="one td_left" data-th="Middle Name">WAYNE</td>
#                         <td class="one td_left" data-th="Sex">M</td>
#                         <td class="one td_left" data-th="Race">B</td>
#                         <td class="one td_right" data-th="Age">36</td>
#                         <td class="one td_left" data-th="City">COLUMBIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24820&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">DOWNS</td>
#                         <td class="two td_left" data-th="First Name">WILLIAM</td>
#                         <td class="two td_left" data-th="Middle Name">CHARLES</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">42</td>
#                         <td class="two td_left" data-th="City">JEFFERSON CITY</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=54428&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="odd">
#                         <td class="one td_left" data-th="Last Name">DUGAN</td>
#                         <td class="one td_left" data-th="First Name">KAYLA</td>
#                         <td class="one td_left" data-th="Middle Name">NICOLE</td>
#                         <td class="one td_left" data-th="Sex">F</td>
#                         <td class="one td_left" data-th="Race">W</td>
#                         <td class="one td_right" data-th="Age">29</td>
#                         <td class="one td_left" data-th="City">CALIFORNIA</td>
#                         <td class="one td_left" data-th="State">MO</td>
#                         <td class="one td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=47501&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="even">
#                         <td class="two td_left" data-th="Last Name">DUNCAN</td>
#                         <td class="two td_left" data-th="First Name">DUSTY</td>
#                         <td class="two td_left" data-th="Middle Name">LANE</td>
#                         <td class="two td_left" data-th="Sex">M</td>
#                         <td class="two td_left" data-th="Race">W</td>
#                         <td class="two td_right" data-th="Age">22</td>
#                         <td class="two td_left" data-th="City">COLUMBIA</td>
#                         <td class="two td_left" data-th="State">MO</td>
#                         <td class="two td_left" data-th>
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67898&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt">&nbsp;</i>Details</a>
# </td>
#                     </tr>
# <!--   -->
#                     <tr class="tr-paging">
#                         <th class="th_left paging_row bottomPaging" colspan="93">&nbsp; Detainee Count:&nbsp;242
#                             <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#                             <ul>
#                                 <li>
# <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)"><i class="fa fa-angle-double-left fa-large">&nbsp;</i></a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)"><i class="fa fa-angle-left fa-large">&nbsp;</i></a>
# </li>
#                                 <li class="disabled">
# <a href="#">Page 1 of 5</a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)"><i class="fa fa-angle-right fa-large">&nbsp;</i></a>
# </li>
#                                 <li>
# <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)"><i class="fa fa-angle-double-right fa-large">&nbsp;</i></a>
# </li>
#                             </ul>
#                             </div>
#                         </th>
#                     </tr>
#                 </tbody>
#             </table>
# <!-- End data table -->
#             <div class="viewCount"><strong>This page has been viewed <html>
#     <head>        <title></title>
#     </head>
#
#     <body>
#         1,855,158
#     </body>
# </html> times since 1/3/06</strong></div>
# <!-- End Background Table -->
# <div id="hiddenfields" class="back" contenteditable="false">
# <input TYPE="hidden" name="slnk" value="0" />
# <input TYPE="hidden" name="sort_col" value="LASTNP" />
# <input TYPE="hidden" name="sort_typ" value="1" />
# <input TYPE="hidden" name="cur_sort_col" value="" />
# <input TYPE="hidden" name="reorder" value="" />
# <input type="hidden" NAME="pageName" value="" />
# <input type="hidden" NAME="preview" value="0" />
# <input type="hidden" name="debug" value="0" />
# <input type="hidden" name="pageNum" value="1" />
# <input type="hidden" name="total_pages" value="5" />
# <input type="hidden" name="total_rows" value=242 />
# <input type="hidden" name="ajax_form" id="ajax_form" value="0" />
# <input type="hidden" NAME="auto_refresh" value="0" />
# <input TYPE="hidden" name="excel" id="toexcel" value="0" />
# <input TYPE="hidden" name="use_udview" id="use_udview" value="0" />
#           </div></form>
#         </div>
#
# <!-- Begin mrc Footer -->
# <!-- Begin Boone County Default Footer -->
# <!-- Begin Bottom Lines of Text -->
# <div class="foottext">
#   <div class="footerMenuLinks noPrint">
#     <a href="http://showmeboone.com" title="www.showmeboone.com">Home</a> |
#       <a href="http://showmeboone.com/home/accessibility.asp" title="Accessibility">Accessibility</a> |
#       <a href="http://showmeboone.com/Home/CountyOfficials.asp" title="County Officials">County Officials</a> |
#       <a href="http://showmeboone.com/Home/ContactUs.asp" title="Hours &amp; Location">Hours &amp; Location</a> |
#     <a href="http://showmeboone.com/Home/sitemap.asp" title="Site Map">Site Map</a> |
#      <a href="http://showmeboone.com/redirect.asp?url=http://oseda.missouri.edu/cgi-bin/countypage?29019" title="County Fact Sheet">County Fact Sheet</a>
#   <p/>
#   <div class="footerMenuLinksRow">
#     <a href="http://showmeboone.com/ASSESSOR/" target="_top" title="Assessor">Assessor</a>  |
#     <a href="http://showmeboone.com/AUDITOR/" target="_top" title="Auditor">Auditor</a>  |
#     <a href="http://showmeboone.com/CLERK/" target="_top" title="County Clerk">County Clerk</a>  |
#     <a href="http://showmeboone.com/COLLECTOR/" target="_top" title="Collector">Collector</a>  |
#     <a href="http://showmeboone.com/COMMISSION/" target="_top" title="Commission">Commission</a> |
#     <a href="http://showmeboone.com/HR/" target="_top" title="Human Resources">Human Resources</a>  |
#     <a href="http://showmeboone.com/GIS/" target="_top" title="GIS">GIS</a>
#   </div>
#   <div class="footerMenuLinksRow">
#     <a href="https://showmeboone.com/BCJC/" target="_top" title="Joint Communications">Joint Communications</a> |
#     <a href="http://showmeboone.com/PA/" target="_top" title="Prosecuting Attorney">Prosecuting Attorney</a> |
#     <a href="http://showmeboone.com/publicworks/" target="_top" title="Public Works">Public Works</a> |
#     <a href="http://showmeboone.com/PURCHASING/" target="_top" title="Purchasing">Purchasing</a> |
#     <a href="http://showmeboone.com/PUBLICADMIN/" target="_top" title="Public Administrator">Public Administrator</a>
#   </div>
#   <div class="footerMenuLinksRow">
#     <a href="http://showmeboone.com/RECORDER/" target="_top" title="Recorder of Deeds">Recorder of Deeds</a>  |
#     <a href="http://showmeboone.com/ResourceManagement/" target="_top" title="Resource Management">Resource Management</a> |
#     <a href="http://www.boonecountymo.org/sheriff/" target="_top" title="Sheriff">Sheriff</a>  |
#     <a href="http://showmeboone.com/TREASURER/" target="_top" title="Treasurer">Treasurer</a>
#   </div>
#   </div>
# <p class="noPrint footerListservLink" style="text-align:center; font-weight: bold;"><a href="https://www.showmeboone.com/countylistserv.asp" class="email" target="_top" title="Subscribe to the Boone County News email list">Subscribe</a> to the Boone County News email list.</p>
#   Copyright &#169; 2017 Boone County, Missouri.  All rights reserved.<br/>
#   This Web application was developed by <a href="http://www.boonecountymo.org">Boone County</a>.
# </div>
# <!-- End Bottom Lines of Text -->
# <!-- End Boone County Default Footer -->
#
# </div>
# <!-- End mrc Footer -->
# <!-- do not delete this comment.
# -->
# <!-- Template date: 2014-08-29 -->
# </body>
# </html>

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Current Detainees of Boone County Jail
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible" />
#   <meta content="width=device-width, initial-scale=1.0" name="viewport" />
#   <!-- -->
#   <!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->
#   <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon" />
#   <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css" />
#   <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css" />
#   <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css" />
#   <!--[if !IE]&gt;
# &lt;link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet"  /&gt;
# &lt;![endif]-->
#   <!--[if IE 7]&gt;
# &lt;link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet"  /&gt;
# &lt;![endif]-->
#   <style type="text/css">
#    #sort_table_head a {pointer-events: none;}
#           #sort_table_head i {display: none;}
#       #sort_table_head [data-col="LASTNP"] a,
#       #sort_table_head [data-col="FIRSTP"] a {
#             pointer-events: initial;}
#       #sort_table_head [data-col="LASTNP"] i,
#       #sort_table_head [data-col="FIRSTP"] i {
#             display: initial;}
#           .viewCount {text-align: center;}
#           .filterOptions.mobileOnly {display: none;}
#           /*@media screen and (min-width: 761px) {
#             body &gt; div.ui-dialog {
#               top: 50% !important;
#               transform: translateY(-50%);
#             }
#           }*/
#   </style>
#   <script type="text/javascript" src="/mrcjava/mrcclasses/mpowerapps.js">
#   </script>
#   <script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" mrcfile="mobileSortAndFilter.js">
#   </script>
#   <script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" mrcfile="websiteNotification.js">
#   </script>
#   <script type="text/javascript">
#    var s1 = new Image().src = '/mrcjava/image/ascg.gif',
#           s0 = new Image().src = '/mrcjava/image/descg.gif';
#   </script>
#  </head>
#  <body>
#   <!-- Begin mrc Header -->
#   <div class="page-wrap">
#    <!-- -->
#    <!-- Begin mrc Default Desktop Header -->
#    <!-- Begin JavaScript Required Message -->
#    <noscript>
#     <div class="warning noJS">
#      The Boone County website
#      <strong>
#       requires
#      </strong>
#      JavaScript to function correctly. Please enable JavaScript in your browser.
#     </div>
#    </noscript>
#    <!-- End JavaScript Required Message -->
#    <!-- Begin Image Bar -->
#    <div class="pageHeader DepartmentHeader container">
#     <div class="DepartmentHeaderGraphic">
#      <img src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" alt="Boone County Sheriff's Badge" />
#     </div>
#     <div class="DepartmentHeaderInfo">
#      <div class="DepartmentHeaderTitle">
#       Boone County Sheriff's Department
#      </div>
#      <div class="container">
#       <div class="DepartmentHeaderAddress">
#        Boone County Sheriff's Department
#        <br />
#        2121 County Dr.
#        <br />
#        Columbia, MO 65202
#       </div>
#       <div class="DepartmentHeaderNumbers">
#        Office (573) 875-1111
#        <br />
#        Fax (573) 874-8953
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- End Image Bar -->
#    <!-- Begin Link Bar -->
#    <div id="headerMenu" class="container noPrint">
#     <ul>
#      <li>
#       <a href="http://www.boonecountymo.org/sheriff">
#        Home
#       </a>
#      </li>
#      <li class="mainMenu">
#       <a href="/mrcjava/servlet/SH01_MP.I00040s">
#        Menu
#       </a>
#      </li>
#      <li>
#       <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">
#        Help
#       </a>
#      </li>
#      <!--&lt;li class="options"&gt;
#       &lt;a href="#"  onclick="viewOptions();"&gt;
#         Options
#       &lt;/a&gt;
#     &lt;/li&gt;-->
#     </ul>
#    </div>
#    <!-- End Link Bar -->
#    <!-- End mrc Default Desktop Header -->
#    <!-- Begin BC Custom Mobile Header-->
#    <div class="fixedHeader">
#     <div class="fixedHeaderButton bcSealButton">
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       <img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" class="bcSeal shBadge" />
#      </a>
#     </div>
#     <div class="fixedHeaderButton menuButton">
#      <!--Link to custom menu page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00040s">
#       Menu
#      </a>
#     </div>
#     <!--&lt;div class="options fixedHeaderButton optionsButton"&gt;
#   &lt;a class="transparent" href="#" id="options" onclick="viewOptions();"&gt;
#     &lt;i class="fa fa-2x fa-gear optionsIcon"&gt;&nbsp;&lt;/i&gt;
#   &lt;/a&gt;
#   &lt;/div&gt;-->
#     <div class="fixedHeaderButton helpButton">
#      <!--Link to help page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00030s">
#       Help
#      </a>
#     </div>
#     <div class="fixedHeaderButton optionsButton hiddenButton">
#     </div>
#     <div class="headerTitle">
#      <!--Link to department home page-->
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       Boone County Sheriff's Department
#      </a>
#     </div>
#    </div>
#    <!-- End BC Custom Mobile Header-->
#    <script type="text/javascript">
#     if (window.location.hostname == "s10ccd5c.boonecountymo.org") {
#    jQuery('a[href="/mrcjava/servlet/BC00_MP.mrcMenu"]').attr(
#      'href',
#      '/mrcjava/servlet/MRCTEST.mrcMenu'
#    );
#  }
#    </script>
#    <!-- -->
#    <!-- End mrc Header -->
#    <!-- Begin Title Bar -->
#    <div class="title">
#     Current Detainees of Boone County Jail
#    </div>
#    <!-- End Title Bar -->
#    <!-- -->
#    <div style="padding: 10px; DISPLAY: none; FONT: 8pt verdana;" id="applicationOptions">
#     <table class="collapse BCSDTable shadow" cellspacing="0" cellpadding="0">
#      <tbody>
#       <tr class="even">
#        <!-- -->
#        <td class="two" valign="top" style="border-bottom:1px solid #000">
#         <table border="0" cellspacing="1" cellpadding="1" width="350" class="BCSDTable">
#          <tbody>
#           <tr>
#            <th>
#             Saved Searches
#            </th>
#           </tr>
#           <tr>
#            <td style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px" align="left">
#             <div id="search_input">
#              <br />
#              <font size="2">
#               <strong>
#                Name Current Search:
#               </strong>
#               <br />
#              </font>
#              &nbsp;&nbsp;&nbsp;
#              <input id="dialogViewName" size="35" name="dialogViewName" />
#              &nbsp;
#              <img style="CURSOR: pointer" onclick="saveView();" alt="" width="20" height="19" src="/mrcjava/image/view_save.png" />
#              <br />
#             </div>
#             <br />
#             <font size="2">
#              <strong>
#               Execute Saved Search:
#              </strong>
#             </font>
#             <br />
#             <table mrc_app="SH01_MP.I00290s" border="0" cellspacing="1" cellpadding="1">
#              <tbody>
#              </tbody>
#             </table>
#             <br />
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#        <!-- -->
#        <td class="two" valign="top" style="border-bottom:1px solid #000">
#         <table border="0" cellspacing="1" cellpadding="1" width="200" class="BCSDTable">
#          <tbody>
#           <tr>
#            <th>
#             Browser Mode
#            </th>
#           </tr>
#           <tr>
#            <td style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px" align="left">
#             <br />
#             <font size="2">
#              <strong>
#               Select Browsing Mode:
#              </strong>
#             </font>
#             <br />
#             <br />
#             <table id="device_select_table" border="0" cellspacing="1" cellpadding="1">
#              <tbody>
#               <tr>
#                <td>
#                 &nbsp;
#                 <img src="/mrcjava/image/check.png" />
#                </td>
#                <td>
#                 <font size="2">
#                  &nbsp;&nbsp;
#                  <a href="#" class="standard" onclick="switchDevice('pc')">
#                   PC
#                  </a>
#                 </font>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                 &nbsp;&nbsp;
#                </td>
#                <td>
#                 <font size="2">
#                  &nbsp;&nbsp;
#                  <a href="#" class="standard" onclick="switchDevice('mob')">
#                   Mobile
#                  </a>
#                 </font>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <!-- -->
#    <div class="ajax_content table-wrapper box-shadow" id="mrcMainContent">
#     <form action="SH01_MP.I00290s" autocomplete="off" data-app_type="I" id="FORM_I00290" method="post" name="FORM_I00290">
#      <!-- Begin Run Time Message -->
#      <div class="errortext1">
#      </div>
#      <!-- End Run Time Message -->
#      <div class="searchWrapper">
#       <div class="search card">
#        <div class="card-title">
#         Search By Name
#        </div>
#        <div class="card-block">
#         <div>
#          <label>
#           Last Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="32" title="val_LASTNP" type="text" value="" />
#         </div>
#         <div>
#          <label>
#           First Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="32" title="val_FIRSTP" type="text" value="" />
#         </div>
#         <div>
#          <button class="btn btn-primary" name="btn_search" type="submit">
#           <i class="fa fa-large fa-search">
#            &nbsp;
#           </i>
#           Search
#          </button>
#          <button class="btn btn-default" name="btn_reset" type="reset">
#           <i class="fa fa-large fa-repeat">
#            &nbsp;
#           </i>
#           Reset
#          </button>
#          <a class="btn btn-default" href="SH01_MP.R00250s?run=2">
#           <i class="fa fa-large fa-file-excel-o">
#            &nbsp;
#           </i>
#           Export Detainees &amp; Charges to Excel
#          </a>
#         </div>
#        </div>
#        <div class="card-block">
#         <strong>
#          Run Date: 10/10/17
#         </strong>
#        </div>
#       </div>
#      </div>
#      <!-- Begin Data Table -->
#      <script>
#       jQuery(document).ready(function(){         var greynames=new Array("s1LASTNP","s1FIRSTP","s1MIDDLP","s1PERKEP"); setSortImage2(greynames,'FORM_I00290'); });
#      </script>
#      <table cellspacing="0" class="collapse data-table shadow responsive">
#       <thead>
#        <tr class="tr-paging">
#         <th class="th_left paging_row" colspan="93">
#          &nbsp;
#          <!-- -->
#          <!--&lt;button class="btn btn-primary" name="btn_search" type="submit"&gt;&lt;i class="fa fa-large fa-filter"&gt;&nbsp;&lt;/i&gt; Filter&lt;/button&gt;-->
#          &nbsp;242 Total Items &nbsp;|&nbsp; Page Size&nbsp;
#          <input class="mrcinput" name="max_rows" size="3" title="max_rowsp" type="text" value="50" />
#          &nbsp;
#          <!-- -->
#          <!--
# &lt;img alt class="to-excel-img" src="/mrcjava/image/format_excel.png" title="Microsoft Excel format"  /&gt; &nbsp; -->
#          <!-- -->
#          <div class="pagination pagination-right fixed-pagination">
#           <ul>
#            <li>
#             <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#              <i class="fa fa-angle-double-left fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#              <i class="fa fa-angle-left fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li class="disabled">
#             <a href="#">
#              Page 1 of 5
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#              <i class="fa fa-angle-right fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#              <i class="fa fa-angle-double-right fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </th>
#        </tr>
#        <!--BEGIN_SORT_TABLE_HEADER-->
#        <tr class="table-header" id="sort_table_head">
#         <th data-col="LASTNP">
#          <a class="sort-col" data-field="LASTNP" href="javascript:void(0)">
#           Last Name&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th data-col="FIRSTP">
#          <a class="sort-col" data-field="FIRSTP" href="javascript:void(0)">
#           First Name&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="MIDDLP">
#          <a class="sort-col" data-field="MIDDLP" href="javascript:void(0)">
#           Middle Name&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="SEXCOP">
#          <a class="sort-col" data-field="SEXCOP" href="javascript:void(0)">
#           Sex&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="RACECP">
#          <a class="sort-col" data-field="RACECP" href="javascript:void(0)">
#           Race&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="AGEBEP">
#          <a class="sort-col" data-field="AGEBEP" href="javascript:void(0)">
#           Age&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="CITYMP">
#          <a class="sort-col" data-field="CITYMP" href="javascript:void(0)">
#           City
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="STATEP">
#          <a class="sort-col" data-field="STATEP" href="javascript:void(0)">
#           State&nbsp;
#           <i class="fa fa-sort">
#            &nbsp;
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile">
#          &nbsp;
#         </th>
#        </tr>
#        <!--END_SORT_TABLE_HEADER-->
#        <!--BEGIN_ADVANCED_SEARCH-->
#        <!-- -->
#        <tr id="search_table_head" style="display: none;">
#         <th align="center">
#          <a class="nav" href="/mrcjava/mrcclasses/filter_relationship_help.html" linkedtype="linkedtype" target="_blank" title="Filter Relationship Help">
#           ?
#          </a>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="6" title="val_LASTNP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="6" title="val_FIRSTP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_MIDDLP" name="rls_MIDDLP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_MIDDLP" name="val_MIDDLP" size="6" title="val_MIDDLP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_SEXCOP" name="rls_SEXCOP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_SEXCOP" name="val_SEXCOP" size="6" title="val_SEXCOP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_RACECP" name="rls_RACECP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_RACECP" name="val_RACECP" size="6" title="val_RACECP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_AGEBEP" name="rls_AGEBEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_AGEBEP" name="val_AGEBEP" size="6" title="val_AGEBEP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_CITYMP" name="rls_CITYMP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_CITYMP" name="val_CITYMP" size="6" title="val_CITYMP" type="text" value="" />
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_STATEP" name="rls_STATEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_STATEP" name="val_STATEP" size="6" title="val_STATEP" type="text" value="" />
#         </th>
#         <th align="center">
#          &nbsp;
#         </th>
#        </tr>
#        <!-- -->
#       </thead>
#       <!--END_ADVANCED_SEARCH-->
#       <tbody class="stripe" id="mrc_main_table">
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ADAM
#         </td>
#         <td class="one td_left" data-th="First Name">
#          OMER
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          SIRAJ
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          29
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          AKERS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          BRANDEN
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          MICHAEL
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          32
#         </td>
#         <td class="two td_left" data-th="City">
#          MOKANE
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=51443&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ALLEN
#         </td>
#         <td class="one td_left" data-th="First Name">
#          WILLIAM
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LAMAR
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          55
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=19022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ANDERSON
#         </td>
#         <td class="two td_left" data-th="First Name">
#          RICHARD
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          KENNETH
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          24
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          AVALOS-AVALOS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JOSE
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          H
#         </td>
#         <td class="one td_right" data-th="Age">
#          19
#         </td>
#         <td class="one td_left" data-th="City">
#          ST.ANN
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78424&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BARNEY
#         </td>
#         <td class="two td_left" data-th="First Name">
#          FELSON
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          DEVONE
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          40
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=4285&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BARRON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          DUSTYN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          MICHAEL
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          20
#         </td>
#         <td class="one td_left" data-th="City">
#          HARTSBURG
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74098&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BLAIR
#         </td>
#         <td class="two td_left" data-th="First Name">
#          RYAN
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          WADE
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          26
#         </td>
#         <td class="two td_left" data-th="City">
#          MEXICO
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73590&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BLOCKER
#         </td>
#         <td class="one td_left" data-th="First Name">
#          TRAMELL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LAMARR
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          39
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BOLEYN
#         </td>
#         <td class="two td_left" data-th="First Name">
#          TRENTON
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          DEAN
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          36
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78034&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BONAPARTE
#         </td>
#         <td class="one td_left" data-th="First Name">
#          NATHANIEL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LEROY
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          38
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=18384&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BOSS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JAFARI
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          RASHIDI
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          34
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BRADEN
#         </td>
#         <td class="one td_left" data-th="First Name">
#          WILLIAM
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          CHRISTOPHER
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          17
#         </td>
#         <td class="one td_left" data-th="City">
#          HALLSVILLE
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79750&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BRADSHAW
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JOSEPH
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          LEE
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          41
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BRASHIER
#         </td>
#         <td class="one td_left" data-th="First Name">
#          APRIL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          RAE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          43
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=1262&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BRILL
#         </td>
#         <td class="two td_left" data-th="First Name">
#          BRANDON
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          NICHOLAS
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          26
#         </td>
#         <td class="two td_left" data-th="City">
#          CLARK
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
# ...
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DANIELSSON
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JESSE
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          ROBERTO
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          24
#         </td>
#         <td class="two td_left" data-th="City">
#          LAYTON
#         </td>
#         <td class="two td_left" data-th="State">
#          UT
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DAVIS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          KAYLA
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          REBECCA
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          27
#         </td>
#         <td class="one td_left" data-th="City">
#          WOOLRIDGE
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61234&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DAWSON
#         </td>
#         <td class="two td_left" data-th="First Name">
#          VINCENT
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          GESHAI
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          20
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72780&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DAY
#         </td>
#         <td class="one td_left" data-th="First Name">
#          MICHAEL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          BRIAN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          46
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79549&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DICKERSON
#         </td>
#         <td class="two td_left" data-th="First Name">
#          CHRISTOPHER
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          KEWESI
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          19
#         </td>
#         <td class="two td_left" data-th="City">
#          NEW ORLEANS
#         </td>
#         <td class="two td_left" data-th="State">
#          LA
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74118&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DIXON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JAY
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          WAYNE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          36
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24820&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DOWNS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          WILLIAM
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          CHARLES
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          42
#         </td>
#         <td class="two td_left" data-th="City">
#          JEFFERSON CITY
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=54428&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DUGAN
#         </td>
#         <td class="one td_left" data-th="First Name">
#          KAYLA
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          NICOLE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          29
#         </td>
#         <td class="one td_left" data-th="City">
#          CALIFORNIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=47501&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DUNCAN
#         </td>
#         <td class="two td_left" data-th="First Name">
#          DUSTY
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          LANE
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          22
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="data-th">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67898&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#            &nbsp;
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="tr-paging">
#         <th class="th_left paging_row bottomPaging" colspan="93">
#          &nbsp; Detainee Count:&nbsp;242
#          <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#           <ul>
#            <li>
#             <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#              <i class="fa fa-angle-double-left fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#              <i class="fa fa-angle-left fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li class="disabled">
#             <a href="#">
#              Page 1 of 5
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#              <i class="fa fa-angle-right fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#              <i class="fa fa-angle-double-right fa-large">
#               &nbsp;
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </th>
#        </tr>
#       </tbody>
#      </table>
#      <!-- End data table -->
#      <div class="viewCount">
#       <strong>
#        This page has been viewed
#       </strong>
#      </div>
#     </form>
#    </div>
#   </div>
#  </body>
# </html>
# <html>
#  <head>
#   <title>
#   </title>
#  </head>
#  <body>
#   1,855,165
#  </body>
# </html>
# times since 1/3/06
# <!-- End Background Table -->
# <div id="hiddenfields" class="back" contenteditable="false">
#  <input type="hidden" name="slnk" value="0" />
#  <input type="hidden" name="sort_col" value="LASTNP" />
#  <input type="hidden" name="sort_typ" value="1" />
#  <input type="hidden" name="cur_sort_col" value="" />
#  <input type="hidden" name="reorder" value="" />
#  <input type="hidden" name="pageName" value="" />
#  <input type="hidden" name="preview" value="0" />
#  <input type="hidden" name="debug" value="0" />
#  <input type="hidden" name="pageNum" value="1" />
#  <input type="hidden" name="total_pages" value="5" />
#  <input type="hidden" name="total_rows" value="242" />
#  <input type="hidden" name="ajax_form" id="ajax_form" value="0" />
#  <input type="hidden" name="auto_refresh" value="0" />
#  <input type="hidden" name="excel" id="toexcel" value="0" />
#  <input type="hidden" name="use_udview" id="use_udview" value="0" />
# </div>
# <!-- Begin mrc Footer -->
# <!-- Begin Boone County Default Footer -->
# <!-- Begin Bottom Lines of Text -->
# <div class="foottext">
#  <div class="footerMenuLinks noPrint">
#   <a href="http://showmeboone.com" title="www.showmeboone.com">
#    Home
#   </a>
#   |
#   <a href="http://showmeboone.com/home/accessibility.asp" title="Accessibility">
#    Accessibility
#   </a>
#   |
#   <a href="http://showmeboone.com/Home/CountyOfficials.asp" title="County Officials">
#    County Officials
#   </a>
#   |
#   <a href="http://showmeboone.com/Home/ContactUs.asp" title="Hours &amp; Location">
#    Hours &amp; Location
#   </a>
#   |
#   <a href="http://showmeboone.com/Home/sitemap.asp" title="Site Map">
#    Site Map
#   </a>
#   |
#   <a href="http://showmeboone.com/redirect.asp?url=http://oseda.missouri.edu/cgi-bin/countypage?29019" title="County Fact Sheet">
#    County Fact Sheet
#   </a>
#   <p>
#    <div class="footerMenuLinksRow">
#     <a href="http://showmeboone.com/ASSESSOR/" target="_top" title="Assessor">
#      Assessor
#     </a>
#     |
#     <a href="http://showmeboone.com/AUDITOR/" target="_top" title="Auditor">
#      Auditor
#     </a>
#     |
#     <a href="http://showmeboone.com/CLERK/" target="_top" title="County Clerk">
#      County Clerk
#     </a>
#     |
#     <a href="http://showmeboone.com/COLLECTOR/" target="_top" title="Collector">
#      Collector
#     </a>
#     |
#     <a href="http://showmeboone.com/COMMISSION/" target="_top" title="Commission">
#      Commission
#     </a>
#     |
#     <a href="http://showmeboone.com/HR/" target="_top" title="Human Resources">
#      Human Resources
#     </a>
#     |
#     <a href="http://showmeboone.com/GIS/" target="_top" title="GIS">
#      GIS
#     </a>
#    </div>
#    <div class="footerMenuLinksRow">
#     <a href="https://showmeboone.com/BCJC/" target="_top" title="Joint Communications">
#      Joint Communications
#     </a>
#     |
#     <a href="http://showmeboone.com/PA/" target="_top" title="Prosecuting Attorney">
#      Prosecuting Attorney
#     </a>
#     |
#     <a href="http://showmeboone.com/publicworks/" target="_top" title="Public Works">
#      Public Works
#     </a>
#     |
#     <a href="http://showmeboone.com/PURCHASING/" target="_top" title="Purchasing">
#      Purchasing
#     </a>
#     |
#     <a href="http://showmeboone.com/PUBLICADMIN/" target="_top" title="Public Administrator">
#      Public Administrator
#     </a>
#    </div>
#    <div class="footerMenuLinksRow">
#     <a href="http://showmeboone.com/RECORDER/" target="_top" title="Recorder of Deeds">
#      Recorder of Deeds
#     </a>
#     |
#     <a href="http://showmeboone.com/ResourceManagement/" target="_top" title="Resource Management">
#      Resource Management
#     </a>
#     |
#     <a href="http://www.boonecountymo.org/sheriff/" target="_top" title="Sheriff">
#      Sheriff
#     </a>
#     |
#     <a href="http://showmeboone.com/TREASURER/" target="_top" title="Treasurer">
#      Treasurer
#     </a>
#    </div>
#   </p>
#  </div>
#  <p class="noPrint footerListservLink" style="text-align:center; font-weight: bold;">
#   <a href="https://www.showmeboone.com/countylistserv.asp" class="email" target="_top" title="Subscribe to the Boone County News email list">
#    Subscribe
#   </a>
#   to the Boone County News email list.
#  </p>
#  Copyright &#169; 2017 Boone County, Missouri.  All rights reserved.
#  <br />
#  This Web application was developed by
#  <a href="http://www.boonecountymo.org">
#   Boone County
#  </a>
#  .
# </div>
# <!-- End Bottom Lines of Text -->
# <!-- End Boone County Default Footer -->
# <!-- End mrc Footer -->
# <!-- do not delete this comment.
# -->
# <!-- Template date: 2014-08-29 -->

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})
print table.prettify()
# Out:
# <tbody class="stripe" id="mrc_main_table">
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ADAM
#  </td>
#  <td class="one td_left" data-th="First Name">
#   OMER
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SIRAJ
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   29
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   AKERS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   BRANDEN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   32
#  </td>
#  <td class="two td_left" data-th="City">
#   MOKANE
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=51443&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ALLEN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   WILLIAM
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LAMAR
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   55
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=19022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ANDERSON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   RICHARD
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   KENNETH
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   24
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   AVALOS-AVALOS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JOSE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   H
#  </td>
#  <td class="one td_right" data-th="Age">
#   19
#  </td>
#  <td class="one td_left" data-th="City">
#   ST.ANN
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78424&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BARNEY
#  </td>
#  <td class="two td_left" data-th="First Name">
#   FELSON
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DEVONE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   40
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=4285&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BARRON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DUSTYN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   20
#  </td>
#  <td class="one td_left" data-th="City">
#   HARTSBURG
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74098&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BLAIR
#  </td>
#  <td class="two td_left" data-th="First Name">
#   RYAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   WADE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   26
#  </td>
#  <td class="two td_left" data-th="City">
#   MEXICO
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73590&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BLOCKER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   TRAMELL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LAMARR
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   39
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BOLEYN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   TRENTON
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DEAN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   36
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78034&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BONAPARTE
#  </td>
#  <td class="one td_left" data-th="First Name">
#   NATHANIEL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LEROY
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   38
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=18384&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BOSS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAFARI
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RASHIDI
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   34
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRADEN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   WILLIAM
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   CHRISTOPHER
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   17
#  </td>
#  <td class="one td_left" data-th="City">
#   HALLSVILLE
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79750&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRADSHAW
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOSEPH
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   41
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRASHIER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   APRIL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   RAE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   43
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=1262&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRILL
#  </td>
#  <td class="two td_left" data-th="First Name">
#   BRANDON
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   NICHOLAS
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   26
#  </td>
#  <td class="two td_left" data-th="City">
#   CLARK
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   CLAUDE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DAVID
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   52
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   THYRUS
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MONTEZ
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   48
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=45497&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRUNS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   MATTHEW
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ELLIOT
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   21
#  </td>
#  <td class="one td_left" data-th="City">
#   KIRKWOOD
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78785&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BURRIS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   GEOFFREY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DARL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55499&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BUSH
#  </td>
#  <td class="one td_left" data-th="First Name">
#   FRANK
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LADON
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   39
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24142&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CALVERT
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOHN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RAY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   35
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=33863&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CALVIN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KAYLA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ANN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   30
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46476&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CANFIELD
#  </td>
#  <td class="two td_left" data-th="First Name">
#   NATHAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EDWARD
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   35
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CAREAGA
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JOSEPH
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   EUGENE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   47
#  </td>
#  <td class="one td_left" data-th="City">
#   MADISON
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=32072&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CARTER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DARIAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MAURICE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   24
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CARTER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DARREN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DEVON
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   22
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79645&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CARTER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DEMARCO
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RAYDELL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67469&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CASE
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JACOB
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   24
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77603&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CERVANTES
#  </td>
#  <td class="two td_left" data-th="First Name">
#   FERNANDO
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   GUILLEN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   H
#  </td>
#  <td class="two td_right" data-th="Age">
#   24
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67583&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CLARK
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DEVIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   J
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   42
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=30772&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COATES
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOSHUA
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EDWARD
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   36
#  </td>
#  <td class="two td_left" data-th="City">
#   ROCHEPORT
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=52814&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   COCO
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DREW
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   PATRICK
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   37
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35949&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COLEMAN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAMES
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   48
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=16927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   COLEMAN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   WESTLY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SHAWN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   43
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=9851&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COLLINS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DENNIS
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   CARL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   33
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38626&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   COOK
#  </td>
#  <td class="one td_left" data-th="First Name">
#   RICKY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   BLAINE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   46
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=17871&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COPENHAVER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   TONY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EUGENE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   49
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=32022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CORNELL
#  </td>
#  <td class="one td_left" data-th="First Name">
#   GERALD
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   HOLLIS
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   62
#  </td>
#  <td class="one td_left" data-th="City">
#   MURRAY
#  </td>
#  <td class="one td_left" data-th="State">
#   UT
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79355&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CROWLEY
#  </td>
#  <td class="two td_left" data-th="First Name">
#   ROBERT
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   JASON
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   33
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41050&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CROY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   MARANDA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   31
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38647&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DANIELSSON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JESSE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ROBERTO
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   24
#  </td>
#  <td class="two td_left" data-th="City">
#   LAYTON
#  </td>
#  <td class="two td_left" data-th="State">
#   UT
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DAVIS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KAYLA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   REBECCA
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   27
#  </td>
#  <td class="one td_left" data-th="City">
#   WOOLRIDGE
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61234&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DAWSON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   VINCENT
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   GESHAI
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   20
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72780&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DAY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   MICHAEL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   BRIAN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   46
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79549&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DICKERSON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CHRISTOPHER
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   KEWESI
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   19
#  </td>
#  <td class="two td_left" data-th="City">
#   NEW ORLEANS
#  </td>
#  <td class="two td_left" data-th="State">
#   LA
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74118&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DIXON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JAY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   WAYNE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   36
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24820&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DOWNS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   WILLIAM
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   CHARLES
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   42
#  </td>
#  <td class="two td_left" data-th="City">
#   JEFFERSON CITY
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=54428&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DUGAN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KAYLA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   NICOLE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   29
#  </td>
#  <td class="one td_left" data-th="City">
#   CALIFORNIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=47501&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DUNCAN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DUSTY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LANE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="data-th">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67898&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#     &nbsp;
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
# <!-- -->
# <tr class="tr-paging">
#  <th class="th_left paging_row bottomPaging" colspan="93">
#   &nbsp; Detainee Count:&nbsp;242
#   <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#    <ul>
#     <li>
#      <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#       <i class="fa fa-angle-double-left fa-large">
#        &nbsp;
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#       <i class="fa fa-angle-left fa-large">
#        &nbsp;
#       </i>
#      </a>
#     </li>
#     <li class="disabled">
#      <a href="#">
#       Page 1 of 5
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#       <i class="fa fa-angle-right fa-large">
#        &nbsp;
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#       <i class="fa fa-angle-double-right fa-large">
#        &nbsp;
#       </i>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </th>
# </tr>
# </tbody>

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    print row.prettify()
# Out:
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  ADAM
# </td>
# <td class="one td_left" data-th="First Name">
#  OMER
# </td>
# <td class="one td_left" data-th="Middle Name">
#  SIRAJ
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  29
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77695&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  AKERS
# </td>
# <td class="two td_left" data-th="First Name">
#  BRANDEN
# </td>
# <td class="two td_left" data-th="Middle Name">
#  MICHAEL
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  32
# </td>
# <td class="two td_left" data-th="City">
#  MOKANE
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=51443&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  ALLEN
# </td>
# <td class="one td_left" data-th="First Name">
#  WILLIAM
# </td>
# <td class="one td_left" data-th="Middle Name">
#  LAMAR
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  55
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=19022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  ANDERSON
# </td>
# <td class="two td_left" data-th="First Name">
#  RICHARD
# </td>
# <td class="two td_left" data-th="Middle Name">
#  KENNETH
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  24
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  AVALOS-AVALOS
# </td>
# <td class="one td_left" data-th="First Name">
#  JOSE
# </td>
# <td class="one td_left" data-th="Middle Name">
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  H
# </td>
# <td class="one td_right" data-th="Age">
#  19
# </td>
# <td class="one td_left" data-th="City">
#  ST.ANN
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78424&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BARNEY
# </td>
# <td class="two td_left" data-th="First Name">
#  FELSON
# </td>
# <td class="two td_left" data-th="Middle Name">
#  DEVONE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  40
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=4285&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BARRON
# </td>
# <td class="one td_left" data-th="First Name">
#  DUSTYN
# </td>
# <td class="one td_left" data-th="Middle Name">
#  MICHAEL
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  20
# </td>
# <td class="one td_left" data-th="City">
#  HARTSBURG
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74098&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BLAIR
# </td>
# <td class="two td_left" data-th="First Name">
#  RYAN
# </td>
# <td class="two td_left" data-th="Middle Name">
#  WADE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  26
# </td>
# <td class="two td_left" data-th="City">
#  MEXICO
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73590&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BLOCKER
# </td>
# <td class="one td_left" data-th="First Name">
#  TRAMELL
# </td>
# <td class="one td_left" data-th="Middle Name">
#  LAMARR
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  39
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=63477&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BOLEYN
# </td>
# <td class="two td_left" data-th="First Name">
#  TRENTON
# </td>
# <td class="two td_left" data-th="Middle Name">
#  DEAN
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  36
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78034&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BONAPARTE
# </td>
# <td class="one td_left" data-th="First Name">
#  NATHANIEL
# </td>
# <td class="one td_left" data-th="Middle Name">
#  LEROY
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  38
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=18384&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BOSS
# </td>
# <td class="two td_left" data-th="First Name">
#  JAFARI
# </td>
# <td class="two td_left" data-th="Middle Name">
#  RASHIDI
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  34
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60725&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BRADEN
# </td>
# <td class="one td_left" data-th="First Name">
#  WILLIAM
# </td>
# <td class="one td_left" data-th="Middle Name">
#  CHRISTOPHER
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  17
# </td>
# <td class="one td_left" data-th="City">
#  HALLSVILLE
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79750&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BRADSHAW
# </td>
# <td class="two td_left" data-th="First Name">
#  JOSEPH
# </td>
# <td class="two td_left" data-th="Middle Name">
#  LEE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  41
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BRASHIER
# </td>
# <td class="one td_left" data-th="First Name">
#  APRIL
# </td>
# <td class="one td_left" data-th="Middle Name">
#  RAE
# </td>
# <td class="one td_left" data-th="Sex">
#  F
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  43
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=1262&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BRILL
# </td>
# <td class="two td_left" data-th="First Name">
#  BRANDON
# </td>
# <td class="two td_left" data-th="Middle Name">
#  NICHOLAS
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  26
# </td>
# <td class="two td_left" data-th="City">
#  CLARK
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BROWN
# </td>
# <td class="one td_left" data-th="First Name">
#  CLAUDE
# </td>
# <td class="one td_left" data-th="Middle Name">
#  DAVID
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  52
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73834&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BROWN
# </td>
# <td class="two td_left" data-th="First Name">
#  THYRUS
# </td>
# <td class="two td_left" data-th="Middle Name">
#  MONTEZ
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  48
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=45497&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BRUNS
# </td>
# <td class="one td_left" data-th="First Name">
#  MATTHEW
# </td>
# <td class="one td_left" data-th="Middle Name">
#  ELLIOT
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  21
# </td>
# <td class="one td_left" data-th="City">
#  KIRKWOOD
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78785&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  BURRIS
# </td>
# <td class="two td_left" data-th="First Name">
#  GEOFFREY
# </td>
# <td class="two td_left" data-th="Middle Name">
#  DARL
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  28
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55499&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  BUSH
# </td>
# <td class="one td_left" data-th="First Name">
#  FRANK
# </td>
# <td class="one td_left" data-th="Middle Name">
#  LADON
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  39
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24142&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CALVERT
# </td>
# <td class="two td_left" data-th="First Name">
#  JOHN
# </td>
# <td class="two td_left" data-th="Middle Name">
#  RAY
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  35
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=33863&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CALVIN
# </td>
# <td class="one td_left" data-th="First Name">
#  KAYLA
# </td>
# <td class="one td_left" data-th="Middle Name">
#  ANN
# </td>
# <td class="one td_left" data-th="Sex">
#  F
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  30
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46476&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CANFIELD
# </td>
# <td class="two td_left" data-th="First Name">
#  NATHAN
# </td>
# <td class="two td_left" data-th="Middle Name">
#  EDWARD
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  35
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CAREAGA
# </td>
# <td class="one td_left" data-th="First Name">
#  JOSEPH
# </td>
# <td class="one td_left" data-th="Middle Name">
#  EUGENE
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  47
# </td>
# <td class="one td_left" data-th="City">
#  MADISON
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=32072&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CARTER
# </td>
# <td class="two td_left" data-th="First Name">
#  DARIAN
# </td>
# <td class="two td_left" data-th="Middle Name">
#  MAURICE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  24
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CARTER
# </td>
# <td class="one td_left" data-th="First Name">
#  DARREN
# </td>
# <td class="one td_left" data-th="Middle Name">
#  DEVON
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  22
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79645&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CARTER
# </td>
# <td class="two td_left" data-th="First Name">
#  DEMARCO
# </td>
# <td class="two td_left" data-th="Middle Name">
#  RAYDELL
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  22
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67469&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CASE
# </td>
# <td class="one td_left" data-th="First Name">
#  JACOB
# </td>
# <td class="one td_left" data-th="Middle Name">
#  MICHAEL
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  24
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77603&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CERVANTES
# </td>
# <td class="two td_left" data-th="First Name">
#  FERNANDO
# </td>
# <td class="two td_left" data-th="Middle Name">
#  GUILLEN
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  H
# </td>
# <td class="two td_right" data-th="Age">
#  24
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67583&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CLARK
# </td>
# <td class="one td_left" data-th="First Name">
#  DEVIN
# </td>
# <td class="one td_left" data-th="Middle Name">
#  J
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  42
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=30772&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  COATES
# </td>
# <td class="two td_left" data-th="First Name">
#  JOSHUA
# </td>
# <td class="two td_left" data-th="Middle Name">
#  EDWARD
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  36
# </td>
# <td class="two td_left" data-th="City">
#  ROCHEPORT
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=52814&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  COCO
# </td>
# <td class="one td_left" data-th="First Name">
#  DREW
# </td>
# <td class="one td_left" data-th="Middle Name">
#  PATRICK
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  37
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35949&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  COLEMAN
# </td>
# <td class="two td_left" data-th="First Name">
#  JAMES
# </td>
# <td class="two td_left" data-th="Middle Name">
#  MICHAEL
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  48
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=16927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  COLEMAN
# </td>
# <td class="one td_left" data-th="First Name">
#  WESTLY
# </td>
# <td class="one td_left" data-th="Middle Name">
#  SHAWN
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  43
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=9851&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  COLLINS
# </td>
# <td class="two td_left" data-th="First Name">
#  DENNIS
# </td>
# <td class="two td_left" data-th="Middle Name">
#  CARL
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  33
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38626&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  COOK
# </td>
# <td class="one td_left" data-th="First Name">
#  RICKY
# </td>
# <td class="one td_left" data-th="Middle Name">
#  BLAINE
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  46
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=17871&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  COPENHAVER
# </td>
# <td class="two td_left" data-th="First Name">
#  TONY
# </td>
# <td class="two td_left" data-th="Middle Name">
#  EUGENE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  49
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=32022&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CORNELL
# </td>
# <td class="one td_left" data-th="First Name">
#  GERALD
# </td>
# <td class="one td_left" data-th="Middle Name">
#  HOLLIS
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  62
# </td>
# <td class="one td_left" data-th="City">
#  MURRAY
# </td>
# <td class="one td_left" data-th="State">
#  UT
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79355&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  CROWLEY
# </td>
# <td class="two td_left" data-th="First Name">
#  ROBERT
# </td>
# <td class="two td_left" data-th="Middle Name">
#  JASON
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  33
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=41050&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  CROY
# </td>
# <td class="one td_left" data-th="First Name">
#  MARANDA
# </td>
# <td class="one td_left" data-th="Middle Name">
#  LEE
# </td>
# <td class="one td_left" data-th="Sex">
#  F
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  31
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38647&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  DANIELSSON
# </td>
# <td class="two td_left" data-th="First Name">
#  JESSE
# </td>
# <td class="two td_left" data-th="Middle Name">
#  ROBERTO
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  24
# </td>
# <td class="two td_left" data-th="City">
#  LAYTON
# </td>
# <td class="two td_left" data-th="State">
#  UT
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  DAVIS
# </td>
# <td class="one td_left" data-th="First Name">
#  KAYLA
# </td>
# <td class="one td_left" data-th="Middle Name">
#  REBECCA
# </td>
# <td class="one td_left" data-th="Sex">
#  F
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  27
# </td>
# <td class="one td_left" data-th="City">
#  WOOLRIDGE
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61234&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  DAWSON
# </td>
# <td class="two td_left" data-th="First Name">
#  VINCENT
# </td>
# <td class="two td_left" data-th="Middle Name">
#  GESHAI
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  20
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72780&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  DAY
# </td>
# <td class="one td_left" data-th="First Name">
#  MICHAEL
# </td>
# <td class="one td_left" data-th="Middle Name">
#  BRIAN
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  46
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79549&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  DICKERSON
# </td>
# <td class="two td_left" data-th="First Name">
#  CHRISTOPHER
# </td>
# <td class="two td_left" data-th="Middle Name">
#  KEWESI
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  B
# </td>
# <td class="two td_right" data-th="Age">
#  19
# </td>
# <td class="two td_left" data-th="City">
#  NEW ORLEANS
# </td>
# <td class="two td_left" data-th="State">
#  LA
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74118&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  DIXON
# </td>
# <td class="one td_left" data-th="First Name">
#  JAY
# </td>
# <td class="one td_left" data-th="Middle Name">
#  WAYNE
# </td>
# <td class="one td_left" data-th="Sex">
#  M
# </td>
# <td class="one td_left" data-th="Race">
#  B
# </td>
# <td class="one td_right" data-th="Age">
#  36
# </td>
# <td class="one td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24820&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  DOWNS
# </td>
# <td class="two td_left" data-th="First Name">
#  WILLIAM
# </td>
# <td class="two td_left" data-th="Middle Name">
#  CHARLES
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  42
# </td>
# <td class="two td_left" data-th="City">
#  JEFFERSON CITY
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=54428&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="odd">
# <td class="one td_left" data-th="Last Name">
#  DUGAN
# </td>
# <td class="one td_left" data-th="First Name">
#  KAYLA
# </td>
# <td class="one td_left" data-th="Middle Name">
#  NICOLE
# </td>
# <td class="one td_left" data-th="Sex">
#  F
# </td>
# <td class="one td_left" data-th="Race">
#  W
# </td>
# <td class="one td_right" data-th="Age">
#  29
# </td>
# <td class="one td_left" data-th="City">
#  CALIFORNIA
# </td>
# <td class="one td_left" data-th="State">
#  MO
# </td>
# <td class="one td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=47501&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="even">
# <td class="two td_left" data-th="Last Name">
#  DUNCAN
# </td>
# <td class="two td_left" data-th="First Name">
#  DUSTY
# </td>
# <td class="two td_left" data-th="Middle Name">
#  LANE
# </td>
# <td class="two td_left" data-th="Sex">
#  M
# </td>
# <td class="two td_left" data-th="Race">
#  W
# </td>
# <td class="two td_right" data-th="Age">
#  22
# </td>
# <td class="two td_left" data-th="City">
#  COLUMBIA
# </td>
# <td class="two td_left" data-th="State">
#  MO
# </td>
# <td class="two td_left" data-th="data-th">
#  <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67898&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#   <i class="fa fa-large fa-fw fa-list-alt">
#    &nbsp;
#   </i>
#   Details
#  </a>
# </td>
# </tr>
#
# <tr class="tr-paging">
# <th class="th_left paging_row bottomPaging" colspan="93">
#  &nbsp; Detainee Count:&nbsp;242
#  <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#   <ul>
#    <li>
#     <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#      <i class="fa fa-angle-double-left fa-large">
#       &nbsp;
#      </i>
#     </a>
#    </li>
#    <li>
#     <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#      <i class="fa fa-angle-left fa-large">
#       &nbsp;
#      </i>
#     </a>
#    </li>
#    <li class="disabled">
#     <a href="#">
#      Page 1 of 5
#     </a>
#    </li>
#    <li>
#     <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#      <i class="fa fa-angle-right fa-large">
#       &nbsp;
#      </i>
#     </a>
#    </li>
#    <li>
#     <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#      <i class="fa fa-angle-double-right fa-large">
#       &nbsp;
#      </i>
#     </a>
#    </li>
#   </ul>
#  </div>
# </th>
# </tr>

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    for cell in row.findAll('td'):
        print cell.text
# Out:
# ADAM
# OMER
# SIRAJ
# M
# B
# 29
# COLUMBIA
# MO
# &nbsp;Details
# AKERS
# BRANDEN
# MICHAEL
# M
# W
# 32
# MOKANE
# MO
# &nbsp;Details
# ALLEN
# WILLIAM
# LAMAR
# M
# B
# 55
# COLUMBIA
# MO
# &nbsp;Details
# ANDERSON
# RICHARD
# KENNETH
# M
# B
# 24
# COLUMBIA
# MO
# &nbsp;Details
# AVALOS-AVALOS
# JOSE
#
# M
# H
# 19
# ST.ANN
# MO
# &nbsp;Details
# BARNEY
# FELSON
# DEVONE
# M
# B
# 40
# COLUMBIA
# MO
# &nbsp;Details
# BARRON
# DUSTYN
# MICHAEL
# M
# W
# 20
# HARTSBURG
# MO
# &nbsp;Details
# BLAIR
# RYAN
# WADE
# M
# W
# 26
# MEXICO
# MO
# &nbsp;Details
# BLOCKER
# TRAMELL
# LAMARR
# M
# B
# 39
# COLUMBIA
# MO
# &nbsp;Details
# BOLEYN
# TRENTON
# DEAN
# M
# W
# 36
# COLUMBIA
# MO
# &nbsp;Details
# BONAPARTE
# NATHANIEL
# LEROY
# M
# B
# 38
# COLUMBIA
# MO
# &nbsp;Details
# BOSS
# JAFARI
# RASHIDI
# M
# B
# 34
# COLUMBIA
# MO
# &nbsp;Details
# BRADEN
# WILLIAM
# CHRISTOPHER
# M
# W
# 17
# HALLSVILLE
# MO
# &nbsp;Details
# BRADSHAW
# JOSEPH
# LEE
# M
# W
# 41
# COLUMBIA
# MO
# &nbsp;Details
# BRASHIER
# APRIL
# RAE
# F
# W
# 43
# COLUMBIA
# MO
# &nbsp;Details
# BRILL
# BRANDON
# NICHOLAS
# M
# W
# 26
# CLARK
# MO
# &nbsp;Details
# BROWN
# CLAUDE
# DAVID
# M
# W
# 52
# COLUMBIA
# MO
# &nbsp;Details
# BROWN
# THYRUS
# MONTEZ
# M
# B
# 48
# COLUMBIA
# MO
# &nbsp;Details
# BRUNS
# MATTHEW
# ELLIOT
# M
# W
# 21
# KIRKWOOD
# MO
# &nbsp;Details
# BURRIS
# GEOFFREY
# DARL
# M
# W
# 28
# COLUMBIA
# MO
# &nbsp;Details
# BUSH
# FRANK
# LADON
# M
# B
# 39
# COLUMBIA
# MO
# &nbsp;Details
# CALVERT
# JOHN
# RAY
# M
# W
# 35
# COLUMBIA
# MO
# &nbsp;Details
# CALVIN
# KAYLA
# ANN
# F
# W
# 30
# COLUMBIA
# MO
# &nbsp;Details
# CANFIELD
# NATHAN
# EDWARD
# M
# W
# 35
# COLUMBIA
# MO
# &nbsp;Details
# CAREAGA
# JOSEPH
# EUGENE
# M
# W
# 47
# MADISON
# MO
# &nbsp;Details
# CARTER
# DARIAN
# MAURICE
# M
# B
# 24
# COLUMBIA
# MO
# &nbsp;Details
# CARTER
# DARREN
# DEVON
# M
# B
# 22
# COLUMBIA
# MO
# &nbsp;Details
# CARTER
# DEMARCO
# RAYDELL
# M
# B
# 22
# COLUMBIA
# MO
# &nbsp;Details
# CASE
# JACOB
# MICHAEL
# M
# W
# 24
# COLUMBIA
# MO
# &nbsp;Details
# CERVANTES
# FERNANDO
# GUILLEN
# M
# H
# 24
# COLUMBIA
# MO
# &nbsp;Details
# CLARK
# DEVIN
# J
# M
# W
# 42
# COLUMBIA
# MO
# &nbsp;Details
# COATES
# JOSHUA
# EDWARD
# M
# W
# 36
# ROCHEPORT
# MO
# &nbsp;Details
# COCO
# DREW
# PATRICK
# M
# W
# 37
# COLUMBIA
# MO
# &nbsp;Details
# COLEMAN
# JAMES
# MICHAEL
# M
# W
# 48
# COLUMBIA
# MO
# &nbsp;Details
# COLEMAN
# WESTLY
# SHAWN
# M
# W
# 43
# COLUMBIA
# MO
# &nbsp;Details
# COLLINS
# DENNIS
# CARL
# M
# B
# 33
# COLUMBIA
# MO
# &nbsp;Details
# COOK
# RICKY
# BLAINE
# M
# W
# 46
# COLUMBIA
# MO
# &nbsp;Details
# COPENHAVER
# TONY
# EUGENE
# M
# W
# 49
# COLUMBIA
# MO
# &nbsp;Details
# CORNELL
# GERALD
# HOLLIS
# M
# W
# 62
# MURRAY
# UT
# &nbsp;Details
# CROWLEY
# ROBERT
# JASON
# M
# W
# 33
# COLUMBIA
# MO
# &nbsp;Details
# CROY
# MARANDA
# LEE
# F
# W
# 31
# COLUMBIA
# MO
# &nbsp;Details
# DANIELSSON
# JESSE
# ROBERTO
# M
# W
# 24
# LAYTON
# UT
# &nbsp;Details
# DAVIS
# KAYLA
# REBECCA
# F
# W
# 27
# WOOLRIDGE
# MO
# &nbsp;Details
# DAWSON
# VINCENT
# GESHAI
# M
# B
# 20
# COLUMBIA
# MO
# &nbsp;Details
# DAY
# MICHAEL
# BRIAN
# M
# W
# 46
# COLUMBIA
# MO
# &nbsp;Details
# DICKERSON
# CHRISTOPHER
# KEWESI
# M
# B
# 19
# NEW ORLEANS
# LA
# &nbsp;Details
# DIXON
# JAY
# WAYNE
# M
# B
# 36
# COLUMBIA
# MO
# &nbsp;Details
# DOWNS
# WILLIAM
# CHARLES
# M
# W
# 42
# JEFFERSON CITY
# MO
# &nbsp;Details
# DUGAN
# KAYLA
# NICOLE
# F
# W
# 29
# CALIFORNIA
# MO
# &nbsp;Details
# DUNCAN
# DUSTY
# LANE
# M
# W
# 22
# COLUMBIA
# MO
# &nbsp;Details

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    for cell in row.findAll('td'):
        print cell.text.replace('&nbsp;', '')
# Out:
# ADAM
# OMER
# SIRAJ
# M
# B
# 29
# COLUMBIA
# MO
# Details
# AKERS
# BRANDEN
# MICHAEL
# M
# W
# 32
# MOKANE
# MO
# Details
# ALLEN
# WILLIAM
# LAMAR
# M
# B
# 55
# COLUMBIA
# MO
# Details
# ANDERSON
# RICHARD
# KENNETH
# M
# B
# 24
# COLUMBIA
# MO
# Details
# AVALOS-AVALOS
# JOSE
#
# M
# H
# 19
# ST.ANN
# MO
# Details
# BARNEY
# FELSON
# DEVONE
# M
# B
# 40
# COLUMBIA
# MO
# Details
# BARRON
# DUSTYN
# MICHAEL
# M
# W
# 20
# HARTSBURG
# MO
# Details
# BLAIR
# RYAN
# WADE
# M
# W
# 26
# MEXICO
# MO
# Details
# BLOCKER
# TRAMELL
# LAMARR
# M
# B
# 39
# COLUMBIA
# MO
# Details
# BOLEYN
# TRENTON
# DEAN
# M
# W
# 36
# COLUMBIA
# MO
# Details
# BONAPARTE
# NATHANIEL
# LEROY
# M
# B
# 38
# COLUMBIA
# MO
# Details
# BOSS
# JAFARI
# RASHIDI
# M
# B
# 34
# COLUMBIA
# MO
# Details
# BRADEN
# WILLIAM
# CHRISTOPHER
# M
# W
# 17
# HALLSVILLE
# MO
# Details
# BRADSHAW
# JOSEPH
# LEE
# M
# W
# 41
# COLUMBIA
# MO
# Details
# BRASHIER
# APRIL
# RAE
# F
# W
# 43
# COLUMBIA
# MO
# Details
# BRILL
# BRANDON
# NICHOLAS
# M
# W
# 26
# CLARK
# MO
# Details
# BROWN
# CLAUDE
# DAVID
# M
# W
# 52
# COLUMBIA
# MO
# Details
# BROWN
# THYRUS
# MONTEZ
# M
# B
# 48
# COLUMBIA
# MO
# Details
# BRUNS
# MATTHEW
# ELLIOT
# M
# W
# 21
# KIRKWOOD
# MO
# Details
# BURRIS
# GEOFFREY
# DARL
# M
# W
# 28
# COLUMBIA
# MO
# Details
# BUSH
# FRANK
# LADON
# M
# B
# 39
# COLUMBIA
# MO
# Details
# CALVERT
# JOHN
# RAY
# M
# W
# 35
# COLUMBIA
# MO
# Details
# CALVIN
# KAYLA
# ANN
# F
# W
# 30
# COLUMBIA
# MO
# Details
# CANFIELD
# NATHAN
# EDWARD
# M
# W
# 35
# COLUMBIA
# MO
# Details
# CAREAGA
# JOSEPH
# EUGENE
# M
# W
# 47
# MADISON
# MO
# Details
# CARTER
# DARIAN
# MAURICE
# M
# B
# 24
# COLUMBIA
# MO
# Details
# CARTER
# DARREN
# DEVON
# M
# B
# 22
# COLUMBIA
# MO
# Details
# CARTER
# DEMARCO
# RAYDELL
# M
# B
# 22
# COLUMBIA
# MO
# Details
# CASE
# JACOB
# MICHAEL
# M
# W
# 24
# COLUMBIA
# MO
# Details
# CERVANTES
# FERNANDO
# GUILLEN
# M
# H
# 24
# COLUMBIA
# MO
# Details
# CLARK
# DEVIN
# J
# M
# W
# 42
# COLUMBIA
# MO
# Details
# COATES
# JOSHUA
# EDWARD
# M
# W
# 36
# ROCHEPORT
# MO
# Details
# COCO
# DREW
# PATRICK
# M
# W
# 37
# COLUMBIA
# MO
# Details
# COLEMAN
# JAMES
# MICHAEL
# M
# W
# 48
# COLUMBIA
# MO
# Details
# COLEMAN
# WESTLY
# SHAWN
# M
# W
# 43
# COLUMBIA
# MO
# Details
# COLLINS
# DENNIS
# CARL
# M
# B
# 33
# COLUMBIA
# MO
# Details
# COOK
# RICKY
# BLAINE
# M
# W
# 46
# COLUMBIA
# MO
# Details
# COPENHAVER
# TONY
# EUGENE
# M
# W
# 49
# COLUMBIA
# MO
# Details
# CORNELL
# GERALD
# HOLLIS
# M
# W
# 62
# MURRAY
# UT
# Details
# CROWLEY
# ROBERT
# JASON
# M
# W
# 33
# COLUMBIA
# MO
# Details
# CROY
# MARANDA
# LEE
# F
# W
# 31
# COLUMBIA
# MO
# Details
# DANIELSSON
# JESSE
# ROBERTO
# M
# W
# 24
# LAYTON
# UT
# Details
# DAVIS
# KAYLA
# REBECCA
# F
# W
# 27
# WOOLRIDGE
# MO
# Details
# DAWSON
# VINCENT
# GESHAI
# M
# B
# 20
# COLUMBIA
# MO
# Details
# DAY
# MICHAEL
# BRIAN
# M
# W
# 46
# COLUMBIA
# MO
# Details
# DICKERSON
# CHRISTOPHER
# KEWESI
# M
# B
# 19
# NEW ORLEANS
# LA
# Details
# DIXON
# JAY
# WAYNE
# M
# B
# 36
# COLUMBIA
# MO
# Details
# DOWNS
# WILLIAM
# CHARLES
# M
# W
# 42
# JEFFERSON CITY
# MO
# Details
# DUGAN
# KAYLA
# NICOLE
# F
# W
# 29
# CALIFORNIA
# MO
# Details
# DUNCAN
# DUSTY
# LANE
# M
# W
# 22
# COLUMBIA
# MO
# Details

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    print list_of_cells
# Out:
# [u'ADAM', u'OMER', u'SIRAJ', u'M', u'B', u'29', u'COLUMBIA', u'MO', u'Details']
# [u'AKERS', u'BRANDEN', u'MICHAEL', u'M', u'W', u'32', u'MOKANE', u'MO', u'Details']
# [u'ALLEN', u'WILLIAM', u'LAMAR', u'M', u'B', u'55', u'COLUMBIA', u'MO', u'Details']
# [u'ANDERSON', u'RICHARD', u'KENNETH', u'M', u'B', u'24', u'COLUMBIA', u'MO', u'Details']
# [u'AVALOS-AVALOS', u'JOSE', u'', u'M', u'H', u'19', u'ST.ANN', u'MO', u'Details']
# [u'BARNEY', u'FELSON', u'DEVONE', u'M', u'B', u'40', u'COLUMBIA', u'MO', u'Details']
# [u'BARRON', u'DUSTYN', u'MICHAEL', u'M', u'W', u'20', u'HARTSBURG', u'MO', u'Details']
# [u'BLAIR', u'RYAN', u'WADE', u'M', u'W', u'26', u'MEXICO', u'MO', u'Details']
# [u'BLOCKER', u'TRAMELL', u'LAMARR', u'M', u'B', u'39', u'COLUMBIA', u'MO', u'Details']
# [u'BOLEYN', u'TRENTON', u'DEAN', u'M', u'W', u'36', u'COLUMBIA', u'MO', u'Details']
# [u'BONAPARTE', u'NATHANIEL', u'LEROY', u'M', u'B', u'38', u'COLUMBIA', u'MO', u'Details']
# [u'BOSS', u'JAFARI', u'RASHIDI', u'M', u'B', u'34', u'COLUMBIA', u'MO', u'Details']
# [u'BRADEN', u'WILLIAM', u'CHRISTOPHER', u'M', u'W', u'17', u'HALLSVILLE', u'MO', u'Details']
# [u'BRADSHAW', u'JOSEPH', u'LEE', u'M', u'W', u'41', u'COLUMBIA', u'MO', u'Details']
# [u'BRASHIER', u'APRIL', u'RAE', u'F', u'W', u'43', u'COLUMBIA', u'MO', u'Details']
# [u'BRILL', u'BRANDON', u'NICHOLAS', u'M', u'W', u'26', u'CLARK', u'MO', u'Details']
# [u'BROWN', u'CLAUDE', u'DAVID', u'M', u'W', u'52', u'COLUMBIA', u'MO', u'Details']
# [u'BROWN', u'THYRUS', u'MONTEZ', u'M', u'B', u'48', u'COLUMBIA', u'MO', u'Details']
# [u'BRUNS', u'MATTHEW', u'ELLIOT', u'M', u'W', u'21', u'KIRKWOOD', u'MO', u'Details']
# [u'BURRIS', u'GEOFFREY', u'DARL', u'M', u'W', u'28', u'COLUMBIA', u'MO', u'Details']
# [u'BUSH', u'FRANK', u'LADON', u'M', u'B', u'39', u'COLUMBIA', u'MO', u'Details']
# [u'CALVERT', u'JOHN', u'RAY', u'M', u'W', u'35', u'COLUMBIA', u'MO', u'Details']
# [u'CALVIN', u'KAYLA', u'ANN', u'F', u'W', u'30', u'COLUMBIA', u'MO', u'Details']
# [u'CANFIELD', u'NATHAN', u'EDWARD', u'M', u'W', u'35', u'COLUMBIA', u'MO', u'Details']
# [u'CAREAGA', u'JOSEPH', u'EUGENE', u'M', u'W', u'47', u'MADISON', u'MO', u'Details']
# [u'CARTER', u'DARIAN', u'MAURICE', u'M', u'B', u'24', u'COLUMBIA', u'MO', u'Details']
# [u'CARTER', u'DARREN', u'DEVON', u'M', u'B', u'22', u'COLUMBIA', u'MO', u'Details']
# [u'CARTER', u'DEMARCO', u'RAYDELL', u'M', u'B', u'22', u'COLUMBIA', u'MO', u'Details']
# [u'CASE', u'JACOB', u'MICHAEL', u'M', u'W', u'24', u'COLUMBIA', u'MO', u'Details']
# [u'CERVANTES', u'FERNANDO', u'GUILLEN', u'M', u'H', u'24', u'COLUMBIA', u'MO', u'Details']
# [u'CLARK', u'DEVIN', u'J', u'M', u'W', u'42', u'COLUMBIA', u'MO', u'Details']
# [u'COATES', u'JOSHUA', u'EDWARD', u'M', u'W', u'36', u'ROCHEPORT', u'MO', u'Details']
# [u'COCO', u'DREW', u'PATRICK', u'M', u'W', u'37', u'COLUMBIA', u'MO', u'Details']
# [u'COLEMAN', u'JAMES', u'MICHAEL', u'M', u'W', u'48', u'COLUMBIA', u'MO', u'Details']
# [u'COLEMAN', u'WESTLY', u'SHAWN', u'M', u'W', u'43', u'COLUMBIA', u'MO', u'Details']
# [u'COLLINS', u'DENNIS', u'CARL', u'M', u'B', u'33', u'COLUMBIA', u'MO', u'Details']
# [u'COOK', u'RICKY', u'BLAINE', u'M', u'W', u'46', u'COLUMBIA', u'MO', u'Details']
# [u'COPENHAVER', u'TONY', u'EUGENE', u'M', u'W', u'49', u'COLUMBIA', u'MO', u'Details']
# [u'CORNELL', u'GERALD', u'HOLLIS', u'M', u'W', u'62', u'MURRAY', u'UT', u'Details']
# [u'CROWLEY', u'ROBERT', u'JASON', u'M', u'W', u'33', u'COLUMBIA', u'MO', u'Details']
# [u'CROY', u'MARANDA', u'LEE', u'F', u'W', u'31', u'COLUMBIA', u'MO', u'Details']
# [u'DANIELSSON', u'JESSE', u'ROBERTO', u'M', u'W', u'24', u'LAYTON', u'UT', u'Details']
# [u'DAVIS', u'KAYLA', u'REBECCA', u'F', u'W', u'27', u'WOOLRIDGE', u'MO', u'Details']
# [u'DAWSON', u'VINCENT', u'GESHAI', u'M', u'B', u'20', u'COLUMBIA', u'MO', u'Details']
# [u'DAY', u'MICHAEL', u'BRIAN', u'M', u'W', u'46', u'COLUMBIA', u'MO', u'Details']
# [u'DICKERSON', u'CHRISTOPHER', u'KEWESI', u'M', u'B', u'19', u'NEW ORLEANS', u'LA', u'Details']
# [u'DIXON', u'JAY', u'WAYNE', u'M', u'B', u'36', u'COLUMBIA', u'MO', u'Details']
# [u'DOWNS', u'WILLIAM', u'CHARLES', u'M', u'W', u'42', u'JEFFERSON CITY', u'MO', u'Details']
# [u'DUGAN', u'KAYLA', u'NICOLE', u'F', u'W', u'29', u'CALIFORNIA', u'MO', u'Details']
# [u'DUNCAN', u'DUSTY', u'LANE', u'M', u'W', u'22', u'COLUMBIA', u'MO', u'Details']
# []

# %%
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

print list_of_rows
# Out:
# [[u'ADAM', u'OMER', u'SIRAJ', u'M', u'B', u'29', u'COLUMBIA', u'MO', u'Details'], [u'AKERS', u'BRANDEN', u'MICHAEL', u'M', u'W', u'32', u'MOKANE', u'MO', u'Details'], [u'ALLEN', u'WILLIAM', u'LAMAR', u'M', u'B', u'55', u'COLUMBIA', u'MO', u'Details'], [u'ANDERSON', u'RICHARD', u'KENNETH', u'M', u'B', u'24', u'COLUMBIA', u'MO', u'Details'], [u'AVALOS-AVALOS', u'JOSE', u'', u'M', u'H', u'19', u'ST.ANN', u'MO', u'Details'], [u'BARNEY', u'FELSON', u'DEVONE', u'M', u'B', u'40', u'COLUMBIA', u'MO', u'Details'], [u'BARRON', u'DUSTYN', u'MICHAEL', u'M', u'W', u'20', u'HARTSBURG', u'MO', u'Details'], [u'BLAIR', u'RYAN', u'WADE', u'M', u'W', u'26', u'MEXICO', u'MO', u'Details'], [u'BLOCKER', u'TRAMELL', u'LAMARR', u'M', u'B', u'39', u'COLUMBIA', u'MO', u'Details'], [u'BOLEYN', u'TRENTON', u'DEAN', u'M', u'W', u'36', u'COLUMBIA', u'MO', u'Details'], [u'BONAPARTE', u'NATHANIEL', u'LEROY', u'M', u'B', u'38', u'COLUMBIA', u'MO', u'Details'], [u'BOSS', u'JAFARI', u'RASHIDI', u'M', u'B', u'34', u'COLUMBIA', u'MO', u'Details'], [u'BRADEN', u'WILLIAM', u'CHRISTOPHER', u'M', u'W', u'17', u'HALLSVILLE', u'MO', u'Details'], [u'BRADSHAW', u'JOSEPH', u'LEE', u'M', u'W', u'41', u'COLUMBIA', u'MO', u'Details'], [u'BRASHIER', u'APRIL', u'RAE', u'F', u'W', u'43', u'COLUMBIA', u'MO', u'Details'], [u'BRILL', u'BRANDON', u'NICHOLAS', u'M', u'W', u'26', u'CLARK', u'MO', u'Details'], [u'BROWN', u'CLAUDE', u'DAVID', u'M', u'W', u'52', u'COLUMBIA', u'MO', u'Details'], [u'BROWN', u'THYRUS', u'MONTEZ', u'M', u'B', u'48', u'COLUMBIA', u'MO', u'Details'], [u'BRUNS', u'MATTHEW', u'ELLIOT', u'M', u'W', u'21', u'KIRKWOOD', u'MO', u'Details'], [u'BURRIS', u'GEOFFREY', u'DARL', u'M', u'W', u'28', u'COLUMBIA', u'MO', u'Details'], [u'BUSH', u'FRANK', u'LADON', u'M', u'B', u'39', u'COLUMBIA', u'MO', u'Details'], [u'CALVERT', u'JOHN', u'RAY', u'M', u'W', u'35', u'COLUMBIA', u'MO', u'Details'], [u'CALVIN', u'KAYLA', u'ANN', u'F', u'W', u'30', u'COLUMBIA', u'MO', u'Details'], [u'CANFIELD', u'NATHAN', u'EDWARD', u'M', u'W', u'35', u'COLUMBIA', u'MO', u'Details'], [u'CAREAGA', u'JOSEPH', u'EUGENE', u'M', u'W', u'47', u'MADISON', u'MO', u'Details'], [u'CARTER', u'DARIAN', u'MAURICE', u'M', u'B', u'24', u'COLUMBIA', u'MO', u'Details'], [u'CARTER', u'DARREN', u'DEVON', u'M', u'B', u'22', u'COLUMBIA', u'MO', u'Details'], [u'CARTER', u'DEMARCO', u'RAYDELL', u'M', u'B', u'22', u'COLUMBIA', u'MO', u'Details'], [u'CASE', u'JACOB', u'MICHAEL', u'M', u'W', u'24', u'COLUMBIA', u'MO', u'Details'], [u'CERVANTES', u'FERNANDO', u'GUILLEN', u'M', u'H', u'24', u'COLUMBIA', u'MO', u'Details'], [u'CLARK', u'DEVIN', u'J', u'M', u'W', u'42', u'COLUMBIA', u'MO', u'Details'], [u'COATES', u'JOSHUA', u'EDWARD', u'M', u'W', u'36', u'ROCHEPORT', u'MO', u'Details'], [u'COCO', u'DREW', u'PATRICK', u'M', u'W', u'37', u'COLUMBIA', u'MO', u'Details'], [u'COLEMAN', u'JAMES', u'MICHAEL', u'M', u'W', u'48', u'COLUMBIA', u'MO', u'Details'], [u'COLEMAN', u'WESTLY', u'SHAWN', u'M', u'W', u'43', u'COLUMBIA', u'MO', u'Details'], [u'COLLINS', u'DENNIS', u'CARL', u'M', u'B', u'33', u'COLUMBIA', u'MO', u'Details'], [u'COOK', u'RICKY', u'BLAINE', u'M', u'W', u'46', u'COLUMBIA', u'MO', u'Details'], [u'COPENHAVER', u'TONY', u'EUGENE', u'M', u'W', u'49', u'COLUMBIA', u'MO', u'Details'], [u'CORNELL', u'GERALD', u'HOLLIS', u'M', u'W', u'62', u'MURRAY', u'UT', u'Details'], [u'CROWLEY', u'ROBERT', u'JASON', u'M', u'W', u'33', u'COLUMBIA', u'MO', u'Details'], [u'CROY', u'MARANDA', u'LEE', u'F', u'W', u'31', u'COLUMBIA', u'MO', u'Details'], [u'DANIELSSON', u'JESSE', u'ROBERTO', u'M', u'W', u'24', u'LAYTON', u'UT', u'Details'], [u'DAVIS', u'KAYLA', u'REBECCA', u'F', u'W', u'27', u'WOOLRIDGE', u'MO', u'Details'], [u'DAWSON', u'VINCENT', u'GESHAI', u'M', u'B', u'20', u'COLUMBIA', u'MO', u'Details'], [u'DAY', u'MICHAEL', u'BRIAN', u'M', u'W', u'46', u'COLUMBIA', u'MO', u'Details'], [u'DICKERSON', u'CHRISTOPHER', u'KEWESI', u'M', u'B', u'19', u'NEW ORLEANS', u'LA', u'Details'], [u'DIXON', u'JAY', u'WAYNE', u'M', u'B', u'36', u'COLUMB ...

# %%
import csv
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

outfile = open("./inmates.csv", "wb")
writer = csv.writer(outfile)
writer.writerows(list_of_rows)

# %%
import csv
import requests
from BeautifulSoup import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []
for row in table.findAll('tr')[1:]:
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

outfile = open("./inmates.csv", "wb")
writer = csv.writer(outfile)
writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State"])
writer.writerows(list_of_rows)
